# %%
from __future__ import print_function
import matplotlib.pyplot as plt
import numpy as np

# %%
import torch
import torch.nn as nn
from torch.autograd import Variable
from torchsummary import summary
import torch.utils.data
import gc
import resource
print(torch.__version__)
# Out:
# 0.4.1

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# Assume that we are on a CUDA machine, then this should print a CUDA device:

print(device)
# Out:
# cpu

# %%
batch_size = 256
num_classes = 100
nb_classes = 20
epochs = 50
learning_rate = 3e-4
from keras.datasets import cifar100
from keras.utils import np_utils
(X_train, y_train), (X_test, y_test) = cifar100.load_data('coarse')
(Xf_train, yf_train), (Xf_test, yf_test) = cifar100.load_data('fine')

# print shape of data while model is building
print("{1} train samples, {2} channel{0}, {3}x{4}".format("" if X_train.shape[1] == 1 else "s", *X_train.shape))
print("{1}  test samples, {2} channel{0}, {3}x{4}".format("" if X_test.shape[1] == 1 else "s", *X_test.shape))

# convert class vectors to binary class matrices
Y_train = np_utils.to_categorical(y_train, nb_classes)
Y_test = np_utils.to_categorical(y_test, nb_classes)

# convert class vectors to binary class matrices
Yf_train = np_utils.to_categorical(yf_train, num_classes)
Yf_test = np_utils.to_categorical(yf_test, num_classes)
# Out:
# Using TensorFlow backend.
# 50000 train samples, 32 channels, 32x3
# 10000  test samples, 32 channels, 32x3

# %%
np.shape(Y_train)
# Out:
# (50000, 20)

# %%
tensor_x_train = torch.Tensor(X_train).permute(0,3,1,2)
tensor_x_test = torch.Tensor(X_test).permute(0,3,1,2)
tensor_yc_train = torch.LongTensor(y_train.flatten())
tensor_yf_train = torch.LongTensor(yf_train.flatten())
print(tensor_x_train.shape)
print(tensor_x_test.shape)
print(tensor_yc_train.shape)
print(tensor_yf_train.shape)
# Out:
# torch.Size([50000, 3, 32, 32])
# torch.Size([10000, 3, 32, 32])
# torch.Size([50000])
# torch.Size([50000])

# %%
tensor_yc_test = torch.LongTensor(y_test.flatten())
tensor_yf_test = torch.LongTensor(yf_test.flatten())
print(tensor_x_test.shape)
print(tensor_yc_test.shape)
print(tensor_yf_test.shape)
# Out:
# torch.Size([10000, 3, 32, 32])
# torch.Size([10000])
# torch.Size([10000])

# %%
train_dataset = torch.utils.data.TensorDataset(tensor_x_train,tensor_yc_train,tensor_yf_train)
val_dataset = torch.utils.data.TensorDataset(tensor_x_test,tensor_yc_test,tensor_yf_test)

train_loader = torch.utils.data.DataLoader(dataset=train_dataset,
                                           batch_size=batch_size, 
                                           shuffle=True)

val_loader = torch.utils.data.DataLoader(dataset=val_dataset,
                                          batch_size=batch_size, 
                                          shuffle=True)

# %%
print(len(train_loader))
print(len(val_loader))
# Out:
# 196
# 40

# %%
import math
import torch
from torch.optim import Optimizer


class Adam(Optimizer):
    """Implements Adam algorithm.

    It has been proposed in `Adam: A Method for Stochastic Optimization`_.

    Arguments:
        params (iterable): iterable of parameters to optimize or dicts defining
            parameter groups
        lr (float, optional): learning rate (default: 1e-3)
        betas (Tuple[float, float], optional): coefficients used for computing
            running averages of gradient and its square (default: (0.9, 0.999))
        eps (float, optional): term added to the denominator to improve
            numerical stability (default: 1e-8)
        weight_decay (float, optional): weight decay (L2 penalty) (default: 0)
        amsgrad (boolean, optional): whether to use the AMSGrad variant of this
            algorithm from the paper `On the Convergence of Adam and Beyond`_

    .. _Adam\: A Method for Stochastic Optimization:
        https://arxiv.org/abs/1412.6980
    .. _On the Convergence of Adam and Beyond:
        https://openreview.net/forum?id=ryQu7f-RZ
    """

    def __init__(self, params, lr=1e-3, betas=(0.9, 0.999), eps=1e-8,
                 weight_decay=0, amsgrad=False):
        if not 0.0 <= lr:
            raise ValueError("Invalid learning rate: {}".format(lr))
        if not 0.0 <= eps:
            raise ValueError("Invalid epsilon value: {}".format(eps))
        if not 0.0 <= betas[0] < 1.0:
            raise ValueError("Invalid beta parameter at index 0: {}".format(betas[0]))
        if not 0.0 <= betas[1] < 1.0:
            raise ValueError("Invalid beta parameter at index 1: {}".format(betas[1]))
        defaults = dict(lr=lr, betas=betas, eps=eps,
                        weight_decay=weight_decay, amsgrad=amsgrad)
        super(Adam, self).__init__(params, defaults)

    def __setstate__(self, state):
        super(Adam, self).__setstate__(state)
        for group in self.param_groups:
            group.setdefault('amsgrad', False)
    
    def step(self, alpha, closure=None):
        """Performs a single optimization step.

        Arguments:
            closure (callable, optional): A closure that reevaluates the model
                and returns the loss.
        """
        loss = None
        if closure is not None:
            loss = closure()

        for group in self.param_groups:
            for p in group['params']:
                if p.grad is None:
                    continue
                grad = p.grad.data
                if grad.is_sparse:
                    raise RuntimeError('Adam does not support sparse gradients, please consider SparseAdam instead')
                amsgrad = group['amsgrad']

                state = self.state[p]

                # State initialization
                if len(state) == 0:
                    state['step'] = 0
                    # Exponential moving average of gradient values
                    state['exp_avg'] = torch.zeros_like(p.data)
                    # Exponential moving average of squared gradient values
                    state['exp_avg_sq'] = torch.zeros_like(p.data)
                    if amsgrad:
                        # Maintains max of all exp. moving avg. of sq. grad. values
                        state['max_exp_avg_sq'] = torch.zeros_like(p.data)

                exp_avg, exp_avg_sq = state['exp_avg'], state['exp_avg_sq']
                if amsgrad:
                    max_exp_avg_sq = state['max_exp_avg_sq']
                beta1, beta2 = group['betas']

                state['step'] += 1

                if group['weight_decay'] != 0:
                    grad = grad.add(group['weight_decay'], p.data)

                # Decay the first and second moment running average coefficient
                exp_avg.mul_(beta1).add_(1 - beta1, grad)
                exp_avg_sq.mul_(beta2).addcmul_(1 - beta2, grad, grad)
                if amsgrad:
                    # Maintains the maximum of all 2nd moment running avg. till now
                    torch.max(max_exp_avg_sq, exp_avg_sq, out=max_exp_avg_sq)
                    # Use the max. for normalizing running avg. of gradient
                    denom = max_exp_avg_sq.sqrt().add_(group['eps'])
                else:
                    denom = exp_avg_sq.sqrt().add_(group['eps'])

                bias_correction1 = 1 - beta1 ** state['step']
                bias_correction2 = 1 - beta2 ** state['step']
                step_size = alpha * group['lr'] * math.sqrt(bias_correction2) / bias_correction1

                p.data.addcdiv_(-step_size, exp_avg, denom)

        return loss

# %%
import torch.nn as nn
import torch.nn.functional as F


class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(3, 6, 2) #28*28*6
        self.pool = nn.MaxPool2d(2, 2) #14*14*6
        self.conv2 = nn.Conv2d(6, 16, 5) #5*5*16
        self.fc1 = nn.Linear(16 * 5 * 5, 200)
        self.fc2 = nn.Linear(200, 20)
        self.fc3 = nn.Linear(200, 100)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = x.view(-1, self.num_flat_features(x)) #16 * 5 * 5
        x = F.relu(self.fc1(x))
        y = self.fc2(x)
        z = self.fc3(x)
        return y,z
    
    def num_flat_features(self, x):
        size = x.size()[1:]  # all dimensions except the batch dimension
        num_features = 1
        for s in size:
            num_features *= s
        return num_features


net = Net()

for i in net.parameters():
    print(i.shape)
    
summary(net, (3, 32, 32))
# Out:
# torch.Size([6, 3, 2, 2])
# torch.Size([6])
# torch.Size([16, 6, 5, 5])
# torch.Size([16])
# torch.Size([200, 400])
# torch.Size([200])
# torch.Size([20, 200])
# torch.Size([20])
# torch.Size([100, 200])
# torch.Size([100])
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-867b373da88a> in <module>()
#      35     print(i.shape)
#      36
# ---> 37 summary(net, (3, 32, 32))
#
# NameError: name 'summary' is not defined

# %%
import torch
torch.manual_seed(1337)

# Loss and Optimizer

#Can also try nn.MSELoss()
criterion = nn.CrossEntropyLoss()
optimizer1 = Adam([i for i in net.parameters() if i.shape != torch.Size([100]) and i.shape != torch.Size([100, 200])], lr=learning_rate, weight_decay=0.03)
optimizer2 = Adam([i for i in net.parameters() if i.shape != torch.Size([20]) and i.shape != torch.Size([20, 200])], lr=learning_rate, weight_decay=0.03)

train_acc = []
val_acc = []
trainc_acc = []
valc_acc = []
trainf_acc = []
valf_acc = []

loss_history = []
lossc_history = []
lossf_history = []

for epoch in range(epochs):
    for i, (images, labelc, labelf) in enumerate(train_loader):
        net.train() # Change model to 'train' mode.
    #     for i in range(cnn_training_data_X.shape[0]):
        images = Variable(images, requires_grad=True) #unsqueeze used to make a 4d tensor because 
    #     print images.shape
        labelc = Variable(labelc, requires_grad=False)
        labelf = Variable(labelf, volatile=True)
        #labels = [labelc, labelf]

        # Forward + Backward + Optimize
        net.zero_grad()
        #outputs = net(images)
        
        
        outc, outf = net(images)
        lossc = criterion(outc, labelc)
        lossf = criterion(outf, labelf)
        loss = lossc + lossf
        
        alpha_ = lossf/(lossc+lossf)
        
        #loss = criterion(outputs, labelc)
        #loss.backward()
        
        loss_history.append(loss.data)
        lossc_history.append(lossc.data)
        lossf_history.append(lossf.data)
        
        loss.backward()
        
        
        optimizer1.step(alpha=alpha_.data)
        optimizer2.step(alpha=(1-alpha_.data))
        
        #for f in net.parameters():
            #if f.shape != torch.Size([100]) and f.shape != torch.Size([100, 200]):
            #f.data.sub_(f.grad.data * learning_rate)
        if (i+1) % 20 == 0:
            print(alpha_.data)
            print ('Epoch [%d/%d], Iter [%d/%d] Loss: %.4f, %.4f, %.4f' 
                   %(epoch+1, epochs, i+1, len(X_train.shape)//batch_size, lossc.data, lossf.data,loss.data))
    print('[%d/%d] Loss: %.3f' % (epoch+1, epochs, np.mean(loss_history)))
    
    
    correctc = 0
    correctf = 0
    total = 0
    net.eval()  # Change model to 'eval' mode (BN uses moving mean/var).
    with torch.no_grad():
        for data in train_loader:
            images, labelc, labelf = data
            outputc, outputf = net(images)
            _, predictedc = torch.max(outputc.data, 1)
            _, predictedf = torch.max(outputf.data, 1)
            total += labelc.size(0)
            correctc += (predictedc == labelc).sum().item()
            correctf += (predictedf == labelf).sum().item()
    print(total)
    trainc_acc_val = (100 * correctc / total)
    trainf_acc_val = (100 * correctf / total)
    train_acc_val = (trainc_acc_val + trainf_acc_val)/2.0
    trainc_acc.append(trainc_acc_val)
    trainf_acc.append(trainf_acc_val)
    train_acc.append(train_acc_val)
    print('Accuracy of the network on the 50000 train images coarse: %d %%' % (trainc_acc_val))
    print('Accuracy of the network on the 50000 train images fine: %d %%' % (trainf_acc_val))
    print('Average Accuracy of the network on the 50000 train images: %d %%' % (train_acc_val))
          
    correctc = 0
    correctf = 0
    total = 0
    net.eval()  # Change model to 'eval' mode (BN uses moving mean/var).
    with torch.no_grad():
        for data in val_loader:
            images, labelc, labelf = data
            outputc, outputf = net(images)
            _, predictedc = torch.max(outputc.data, 1)
            _, predictedf = torch.max(outputf.data, 1)
            total += labelc.size(0)
            correctc += (predictedc == labelc).sum().item()
            correctf += (predictedf == labelf).sum().item()

    valc_acc_val = (100 * correctc / total)
    valf_acc_val = (100 * correctf / total)
    val_acc_val = (valc_acc_val + valf_acc_val)/2.0
    valc_acc.append(valc_acc_val)
    valf_acc.append(valf_acc_val)
    val_acc.append(val_acc_val)
    print('Accuracy of the network on the 10000 test images coarse: %d %%' % (valc_acc_val))
    print('Accuracy of the network on the 10000 test images fine: %d %%' % (valf_acc_val))
    print('Average Accuracy of the network on the 10000 test images: %d %%' % (val_acc_val))
# Out:
# /Users/jayanth/Library/Python/2.7/lib/python/site-packages/ipykernel_launcher.py:29: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
# tensor(0.6042)
# Epoch [1/50], Iter [20/0] Loss: 3.4080, 5.2029, 8.6109
# tensor(0.6047)
# Epoch [1/50], Iter [40/0] Loss: 3.0814, 4.7138, 7.7952
# tensor(0.6098)
# Epoch [1/50], Iter [60/0] Loss: 2.9392, 4.5931, 7.5323
# tensor(0.6090)
# Epoch [1/50], Iter [80/0] Loss: 2.9153, 4.5400, 7.4553
# tensor(0.6163)
# Epoch [1/50], Iter [100/0] Loss: 2.7699, 4.4495, 7.2194
# tensor(0.6183)
# Epoch [1/50], Iter [120/0] Loss: 2.7235, 4.4117, 7.1352
# tensor(0.6162)
# Epoch [1/50], Iter [140/0] Loss: 2.7778, 4.4603, 7.2381
# tensor(0.6114)
# Epoch [1/50], Iter [160/0] Loss: 2.7693, 4.3567, 7.1260
# tensor(0.6065)
# Epoch [1/50], Iter [180/0] Loss: 2.7455, 4.2322, 6.9778
# [1/50] Loss: 8.003
# 50000
# Accuracy of the network on the 50000 train images coarse: 20 %
# Accuracy of the network on the 50000 train images fine: 7 %
# Average Accuracy of the network on the 50000 train images: 13 %
# Accuracy of the network on the 10000 test images coarse: 19 %
# Accuracy of the network on the 10000 test images fine: 7 %
# Average Accuracy of the network on the 10000 test images: 13 %
# tensor(0.6067)
# Epoch [2/50], Iter [20/0] Loss: 2.6819, 4.1379, 6.8198
# tensor(0.6153)
# Epoch [2/50], Iter [40/0] Loss: 2.5080, 4.0113, 6.5193
# tensor(0.6152)
# Epoch [2/50], Iter [60/0] Loss: 2.4341, 3.8922, 6.3263
# tensor(0.6113)
# Epoch [2/50], Iter [80/0] Loss: 2.4257, 3.8153, 6.2410
# tensor(0.6095)
# Epoch [2/50], Iter [100/0] Loss: 2.4173, 3.7722, 6.1895
# tensor(0.6163)
# Epoch [2/50], Iter [120/0] Loss: 2.3547, 3.7819, 6.1366
# tensor(0.6151)
# Epoch [2/50], Iter [140/0] Loss: 2.3290, 3.7216, 6.0506
# tensor(0.6064)
# Epoch [2/50], Iter [160/0] Loss: 2.3364, 3.5999, 5.9363
# tensor(0.6171)
# Epoch [2/50], Iter [180/0] Loss: 2.3616, 3.8054, 6.1670
# [2/50] Loss: 7.161
# 50000
# Accuracy of the network on the 50000 train images coarse: 28 %
# Accuracy of the network on the 50000 train images fine: 16 %
# Average Accuracy of the network on the 50000 train images: 22 %
# Accuracy of the network on the 10000 test images coarse: 27 %
# Accuracy of the network on the 10000 test images fine: 15 %
# Average Accuracy of the network on the 10000 test images: 21 %
# tensor(0.6082)
# Epoch [3/50], Iter [20/0] Loss: 2.2412, 3.4784, 5.7197
# tensor(0.6130)
# Epoch [3/50], Iter [40/0] Loss: 2.3249, 3.6826, 6.0075
# tensor(0.6029)
# Epoch [3/50], Iter [60/0] Loss: 2.2912, 3.4792, 5.7704
# tensor(0.6159)
# Epoch [3/50], Iter [80/0] Loss: 2.3503, 3.7686, 6.1188
# tensor(0.6008)
# Epoch [3/50], Iter [100/0] Loss: 2.3088, 3.4749, 5.7837
# tensor(0.6006)
# Epoch [3/50], Iter [120/0] Loss: 2.3120, 3.4762, 5.7882
# tensor(0.6116)
# Epoch [3/50], Iter [140/0] Loss: 2.0970, 3.3019, 5.3989
# tensor(0.6228)
# Epoch [3/50], Iter [160/0] Loss: 2.0544, 3.3920, 5.4464
# tensor(0.6085)
# Epoch [3/50], Iter [180/0] Loss: 2.2142, 3.4417, 5.6559
# [3/50] Loss: 6.718
# 50000
# Accuracy of the network on the 50000 train images coarse: 32 %
# Accuracy of the network on the 50000 train images fine: 20 %
# Average Accuracy of the network on the 50000 train images: 26 %
# Accuracy of the network on the 10000 test images coarse: 30 %
# Accuracy of the network on the 10000 test images fine: 17 %
# Average Accuracy of the network on the 10000 test images: 23 %
# tensor(0.6078)
# Epoch [4/50], Iter [20/0] Loss: 2.2624, 3.5057, 5.7681
# tensor(0.5953)
# Epoch [4/50], Iter [40/0] Loss: 2.2036, 3.2413, 5.4448
# tensor(0.6008)
# Epoch [4/50], Iter [60/0] Loss: 2.3376, 3.5174, 5.8550
# tensor(0.5967)
# Epoch [4/50], Iter [80/0] Loss: 2.2697, 3.3574, 5.6271
# tensor(0.6029)
# Epoch [4/50], Iter [100/0] Loss: 2.1461, 3.2582, 5.4043
# tensor(0.6041)
# Epoch [4/50], Iter [120/0] Loss: 2.1406, 3.2664, 5.4070
# tensor(0.6160)
# Epoch [4/50], Iter [140/0] Loss: 2.0347, 3.2643, 5.2990
# tensor(0.6102)
# Epoch [4/50], Iter [160/0] Loss: 2.2007, 3.4451, 5.6458
# tensor(0.5969)
# Epoch [4/50], Iter [180/0] Loss: 2.3897, 3.5379, 5.9276
# [4/50] Loss: 6.430
# 50000
# Accuracy of the network on the 50000 train images coarse: 34 %
# Accuracy of the network on the 50000 train images fine: 22 %
# Average Accuracy of the network on the 50000 train images: 28 %
# Accuracy of the network on the 10000 test images coarse: 32 %
# Accuracy of the network on the 10000 test images fine: 20 %
# Average Accuracy of the network on the 10000 test images: 26 %
# tensor(0.6064)
# Epoch [5/50], Iter [20/0] Loss: 2.0407, 3.1438, 5.1845
# tensor(0.5912)
# Epoch [5/50], Iter [40/0] Loss: 2.2811, 3.2993, 5.5804
# tensor(0.6063)
# Epoch [5/50], Iter [60/0] Loss: 2.1559, 3.3201, 5.4760
# tensor(0.6039)
# Epoch [5/50], Iter [80/0] Loss: 2.0984, 3.1989, 5.2973
# tensor(0.6096)
# Epoch [5/50], Iter [100/0] Loss: 2.0719, 3.2351, 5.3069
# tensor(0.6003)
# Epoch [5/50], Iter [120/0] Loss: 2.2283, 3.3466, 5.5748
# tensor(0.5914)
# Epoch [5/50], Iter [140/0] Loss: 2.1641, 3.1324, 5.2965
# tensor(0.6030)
# Epoch [5/50], Iter [160/0] Loss: 2.1636, 3.2857, 5.4493
# tensor(0.6046)
# Epoch [5/50], Iter [180/0] Loss: 2.2178, 3.3911, 5.6089
# [5/50] Loss: 6.222
# 50000
# Accuracy of the network on the 50000 train images coarse: 36 %
# Accuracy of the network on the 50000 train images fine: 24 %
# Average Accuracy of the network on the 50000 train images: 30 %
# Accuracy of the network on the 10000 test images coarse: 33 %
# Accuracy of the network on the 10000 test images fine: 21 %
# Average Accuracy of the network on the 10000 test images: 27 %
# tensor(0.6067)
# Epoch [6/50], Iter [20/0] Loss: 2.1062, 3.2489, 5.3552
# tensor(0.5990)
# Epoch [6/50], Iter [40/0] Loss: 2.1217, 3.1687, 5.2904
# tensor(0.6112)
# Epoch [6/50], Iter [60/0] Loss: 1.9727, 3.1012, 5.0739
# tensor(0.6052)
# Epoch [6/50], Iter [80/0] Loss: 2.0808, 3.1901, 5.2710
# tensor(0.5944)
# Epoch [6/50], Iter [100/0] Loss: 2.2371, 3.2781, 5.5152
# tensor(0.6059)
# Epoch [6/50], Iter [120/0] Loss: 2.0564, 3.1617, 5.2181
# tensor(0.6011)
# Epoch [6/50], Iter [140/0] Loss: 2.2159, 3.3388, 5.5547
# tensor(0.6122)
# Epoch [6/50], Iter [160/0] Loss: 2.0410, 3.2217, 5.2627
# tensor(0.5950)
# Epoch [6/50], Iter [180/0] Loss: 2.0652, 3.0347, 5.0999
# [6/50] Loss: 6.059
# 50000
# Accuracy of the network on the 50000 train images coarse: 38 %
# Accuracy of the network on the 50000 train images fine: 26 %
# Average Accuracy of the network on the 50000 train images: 32 %
# Accuracy of the network on the 10000 test images coarse: 35 %
# Accuracy of the network on the 10000 test images fine: 23 %
# Average Accuracy of the network on the 10000 test images: 29 %
# tensor(0.5998)
# Epoch [7/50], Iter [20/0] Loss: 2.0493, 3.0714, 5.1207
# tensor(0.5902)
# Epoch [7/50], Iter [40/0] Loss: 2.0831, 3.0002, 5.0832
# tensor(0.5953)
# Epoch [7/50], Iter [60/0] Loss: 2.0896, 3.0741, 5.1637
# tensor(0.6072)
# Epoch [7/50], Iter [80/0] Loss: 1.8630, 2.8793, 4.7422
# tensor(0.5933)
# Epoch [7/50], Iter [100/0] Loss: 2.0403, 2.9767, 5.0170
# tensor(0.6006)
# Epoch [7/50], Iter [120/0] Loss: 2.0999, 3.1575, 5.2573
# tensor(0.5945)
# Epoch [7/50], Iter [140/0] Loss: 2.1673, 3.1774, 5.3447
# tensor(0.6017)
# Epoch [7/50], Iter [160/0] Loss: 1.9512, 2.9476, 4.8988
# tensor(0.6013)
# Epoch [7/50], Iter [180/0] Loss: 2.0573, 3.1025, 5.1598
# [7/50] Loss: 5.923
# 50000
# Accuracy of the network on the 50000 train images coarse: 39 %
# Accuracy of the network on the 50000 train images fine: 27 %
# Average Accuracy of the network on the 50000 train images: 33 %
# Accuracy of the network on the 10000 test images coarse: 36 %
# Accuracy of the network on the 10000 test images fine: 24 %
# Average Accuracy of the network on the 10000 test images: 30 %
# tensor(0.5981)
# Epoch [8/50], Iter [20/0] Loss: 1.9771, 2.9418, 4.9189
# tensor(0.5977)
# Epoch [8/50], Iter [40/0] Loss: 2.0533, 3.0504, 5.1037
# tensor(0.6067)
# Epoch [8/50], Iter [60/0] Loss: 1.8893, 2.9148, 4.8041
# tensor(0.5872)
# Epoch [8/50], Iter [80/0] Loss: 2.0544, 2.9227, 4.9771
# tensor(0.5991)
# Epoch [8/50], Iter [100/0] Loss: 1.9372, 2.8953, 4.8326
# tensor(0.6064)
# Epoch [8/50], Iter [120/0] Loss: 1.8522, 2.8530, 4.7052
# tensor(0.6072)
# Epoch [8/50], Iter [140/0] Loss: 2.0134, 3.1126, 5.1260
# tensor(0.6030)
# Epoch [8/50], Iter [160/0] Loss: 1.9979, 3.0345, 5.0324
# tensor(0.5933)
# Epoch [8/50], Iter [180/0] Loss: 2.1605, 3.1511, 5.3116
# [8/50] Loss: 5.808
# 50000
# Accuracy of the network on the 50000 train images coarse: 39 %
# Accuracy of the network on the 50000 train images fine: 28 %
# Average Accuracy of the network on the 50000 train images: 33 %
# Accuracy of the network on the 10000 test images coarse: 35 %
# Accuracy of the network on the 10000 test images fine: 24 %
# Average Accuracy of the network on the 10000 test images: 29 %
# tensor(0.6029)
# Epoch [9/50], Iter [20/0] Loss: 1.8902, 2.8700, 4.7603
# tensor(0.6021)
# Epoch [9/50], Iter [40/0] Loss: 1.9113, 2.8921, 4.8034
# tensor(0.6051)
# Epoch [9/50], Iter [60/0] Loss: 2.0439, 3.1313, 5.1752
# tensor(0.5927)
# Epoch [9/50], Iter [80/0] Loss: 2.1017, 3.0590, 5.1607
# tensor(0.6014)
# Epoch [9/50], Iter [100/0] Loss: 2.0380, 3.0744, 5.1124
# tensor(0.6024)
# Epoch [9/50], Iter [120/0] Loss: 1.9476, 2.9503, 4.8979
# tensor(0.5932)
# Epoch [9/50], Iter [140/0] Loss: 1.9774, 2.8840, 4.8614
# tensor(0.5957)
# Epoch [9/50], Iter [160/0] Loss: 2.0038, 2.9526, 4.9564
# tensor(0.5973)
# Epoch [9/50], Iter [180/0] Loss: 1.9971, 2.9619, 4.9590
# [9/50] Loss: 5.707
# 50000
# Accuracy of the network on the 50000 train images coarse: 40 %
# Accuracy of the network on the 50000 train images fine: 29 %
# Average Accuracy of the network on the 50000 train images: 34 %
# Accuracy of the network on the 10000 test images coarse: 36 %
# Accuracy of the network on the 10000 test images fine: 25 %
# Average Accuracy of the network on the 10000 test images: 30 %
# tensor(0.5979)
# Epoch [10/50], Iter [20/0] Loss: 2.0157, 2.9974, 5.0130
# tensor(0.5937)
# Epoch [10/50], Iter [40/0] Loss: 1.9560, 2.8584, 4.8144
# tensor(0.6062)
# Epoch [10/50], Iter [60/0] Loss: 1.8739, 2.8845, 4.7584
# tensor(0.6021)
# Epoch [10/50], Iter [80/0] Loss: 1.8341, 2.7751, 4.6093
# tensor(0.6071)
# Epoch [10/50], Iter [100/0] Loss: 1.8019, 2.7838, 4.5857
# tensor(0.5923)
# Epoch [10/50], Iter [120/0] Loss: 1.9945, 2.8971, 4.8916
# tensor(0.5926)
# Epoch [10/50], Iter [140/0] Loss: 2.1364, 3.1070, 5.2434
# tensor(0.6008)
# Epoch [10/50], Iter [160/0] Loss: 1.8740, 2.8206, 4.6947
# tensor(0.5944)
# Epoch [10/50], Iter [180/0] Loss: 1.9419, 2.8457, 4.7876
# [10/50] Loss: 5.618
# 50000
# Accuracy of the network on the 50000 train images coarse: 41 %
# Accuracy of the network on the 50000 train images fine: 30 %
# Average Accuracy of the network on the 50000 train images: 35 %
# Accuracy of the network on the 10000 test images coarse: 38 %
# Accuracy of the network on the 10000 test images fine: 26 %
# Average Accuracy of the network on the 10000 test images: 32 %
# tensor(0.5814)
# Epoch [11/50], Iter [20/0] Loss: 1.9442, 2.7008, 4.6450
# tensor(0.6038)
# Epoch [11/50], Iter [40/0] Loss: 1.7645, 2.6890, 4.4536
# tensor(0.6022)
# Epoch [11/50], Iter [60/0] Loss: 1.7803, 2.6951, 4.4754
# tensor(0.6074)
# Epoch [11/50], Iter [80/0] Loss: 1.8058, 2.7941, 4.6000
# tensor(0.5971)
# Epoch [11/50], Iter [100/0] Loss: 1.8940, 2.8068, 4.7009
# tensor(0.5896)
# Epoch [11/50], Iter [120/0] Loss: 2.0344, 2.9226, 4.9570
# tensor(0.6065)
# Epoch [11/50], Iter [140/0] Loss: 1.8237, 2.8114, 4.6352
# tensor(0.5979)
# Epoch [11/50], Iter [160/0] Loss: 1.9748, 2.9363, 4.9111
# tensor(0.6076)
# Epoch [11/50], Iter [180/0] Loss: 1.8212, 2.8203, 4.6415
# [11/50] Loss: 5.539
# 50000
# Accuracy of the network on the 50000 train images coarse: 43 %
# Accuracy of the network on the 50000 train images fine: 32 %
# Average Accuracy of the network on the 50000 train images: 37 %
# Accuracy of the network on the 10000 test images coarse: 38 %
# Accuracy of the network on the 10000 test images fine: 27 %
# Average Accuracy of the network on the 10000 test images: 32 %
# tensor(0.6116)
# Epoch [12/50], Iter [20/0] Loss: 1.7290, 2.7224, 4.4514
# tensor(0.6124)
# Epoch [12/50], Iter [40/0] Loss: 1.8254, 2.8847, 4.7101
# tensor(0.5954)
# Epoch [12/50], Iter [60/0] Loss: 1.8563, 2.7320, 4.5882
# tensor(0.5988)
# Epoch [12/50], Iter [80/0] Loss: 1.7698, 2.6417, 4.4115
# tensor(0.5880)
# Epoch [12/50], Iter [100/0] Loss: 1.9763, 2.8203, 4.7966
# tensor(0.5846)
# Epoch [12/50], Iter [120/0] Loss: 1.9958, 2.8086, 4.8044
# tensor(0.5864)
# Epoch [12/50], Iter [140/0] Loss: 2.0274, 2.8747, 4.9021
# tensor(0.5978)
# Epoch [12/50], Iter [160/0] Loss: 1.9471, 2.8939, 4.8410
# tensor(0.5981)
# Epoch [12/50], Iter [180/0] Loss: 1.7326, 2.5781, 4.3108
# [12/50] Loss: 5.465
# 50000
# Accuracy of the network on the 50000 train images coarse: 44 %
# Accuracy of the network on the 50000 train images fine: 33 %
# Average Accuracy of the network on the 50000 train images: 38 %
# Accuracy of the network on the 10000 test images coarse: 39 %
# Accuracy of the network on the 10000 test images fine: 28 %
# Average Accuracy of the network on the 10000 test images: 33 %
# tensor(0.6031)
# Epoch [13/50], Iter [20/0] Loss: 1.8455, 2.8045, 4.6500
# tensor(0.5967)
# Epoch [13/50], Iter [40/0] Loss: 1.7377, 2.5713, 4.3090
# tensor(0.6011)
# Epoch [13/50], Iter [60/0] Loss: 1.8973, 2.8589, 4.7562
# tensor(0.5995)
# Epoch [13/50], Iter [80/0] Loss: 1.8578, 2.7813, 4.6391
# tensor(0.5957)
# Epoch [13/50], Iter [100/0] Loss: 1.8854, 2.7780, 4.6634
# tensor(0.6011)
# Epoch [13/50], Iter [120/0] Loss: 1.7924, 2.7009, 4.4933
# tensor(0.5845)
# Epoch [13/50], Iter [140/0] Loss: 1.8752, 2.6378, 4.5130
# tensor(0.5936)
# Epoch [13/50], Iter [160/0] Loss: 1.8795, 2.7455, 4.6249
# tensor(0.5944)
# Epoch [13/50], Iter [180/0] Loss: 1.7999, 2.6372, 4.4371
# [13/50] Loss: 5.398
# 50000
# Accuracy of the network on the 50000 train images coarse: 44 %
# Accuracy of the network on the 50000 train images fine: 34 %
# Average Accuracy of the network on the 50000 train images: 39 %
# Accuracy of the network on the 10000 test images coarse: 39 %
# Accuracy of the network on the 10000 test images fine: 29 %
# Average Accuracy of the network on the 10000 test images: 34 %
# tensor(0.5852)
# Epoch [14/50], Iter [20/0] Loss: 1.9342, 2.7287, 4.6629
# tensor(0.5963)
# Epoch [14/50], Iter [40/0] Loss: 1.8657, 2.7559, 4.6216
# tensor(0.6016)
# Epoch [14/50], Iter [60/0] Loss: 1.8478, 2.7901, 4.6379
# tensor(0.5933)
# Epoch [14/50], Iter [80/0] Loss: 1.9618, 2.8625, 4.8243
# tensor(0.6012)
# Epoch [14/50], Iter [100/0] Loss: 1.8035, 2.7184, 4.5219
# tensor(0.5983)
# Epoch [14/50], Iter [120/0] Loss: 1.7628, 2.6253, 4.3881
# tensor(0.5951)
# Epoch [14/50], Iter [140/0] Loss: 1.9296, 2.8355, 4.7651
# tensor(0.5965)
# Epoch [14/50], Iter [160/0] Loss: 1.8039, 2.6664, 4.4704
# tensor(0.5990)
# Epoch [14/50], Iter [180/0] Loss: 1.8242, 2.7250, 4.5492
# [14/50] Loss: 5.336
# 50000
# Accuracy of the network on the 50000 train images coarse: 45 %
# Accuracy of the network on the 50000 train images fine: 34 %
# Average Accuracy of the network on the 50000 train images: 39 %
# Accuracy of the network on the 10000 test images coarse: 39 %
# Accuracy of the network on the 10000 test images fine: 29 %
# Average Accuracy of the network on the 10000 test images: 34 %
# tensor(0.5945)
# Epoch [15/50], Iter [20/0] Loss: 1.8371, 2.6930, 4.5302
# tensor(0.6016)
# Epoch [15/50], Iter [40/0] Loss: 1.7028, 2.5714, 4.2741
# tensor(0.5809)
# Epoch [15/50], Iter [60/0] Loss: 1.7468, 2.4214, 4.1683
# tensor(0.5902)
# Epoch [15/50], Iter [80/0] Loss: 1.8953, 2.7299, 4.6252
# tensor(0.5947)
# Epoch [15/50], Iter [100/0] Loss: 1.8513, 2.7160, 4.5672
# tensor(0.6061)
# Epoch [15/50], Iter [120/0] Loss: 1.8812, 2.8951, 4.7763
# tensor(0.5958)
# Epoch [15/50], Iter [140/0] Loss: 1.8993, 2.7999, 4.6992
# tensor(0.5936)
# Epoch [15/50], Iter [160/0] Loss: 1.8210, 2.6598, 4.4808
# tensor(0.6057)
# Epoch [15/50], Iter [180/0] Loss: 1.7574, 2.6994, 4.4568
# [15/50] Loss: 5.279
# 50000
# Accuracy of the network on the 50000 train images coarse: 45 %
# Accuracy of the network on the 50000 train images fine: 34 %
# Average Accuracy of the network on the 50000 train images: 39 %
# Accuracy of the network on the 10000 test images coarse: 39 %
# Accuracy of the network on the 10000 test images fine: 29 %
# Average Accuracy of the network on the 10000 test images: 34 %
# tensor(0.6100)
# Epoch [16/50], Iter [20/0] Loss: 1.6759, 2.6209, 4.2968
# tensor(0.5900)
# Epoch [16/50], Iter [40/0] Loss: 1.9539, 2.8114, 4.7653
# tensor(0.5947)
# Epoch [16/50], Iter [60/0] Loss: 1.8132, 2.6606, 4.4738
# tensor(0.6011)
# Epoch [16/50], Iter [80/0] Loss: 1.7230, 2.5958, 4.3188
# tensor(0.5940)
# Epoch [16/50], Iter [100/0] Loss: 1.7872, 2.6145, 4.4017
# tensor(0.5971)
# Epoch [16/50], Iter [120/0] Loss: 1.8343, 2.7186, 4.5529
# tensor(0.5981)
# Epoch [16/50], Iter [140/0] Loss: 1.9211, 2.8589, 4.7800
# tensor(0.6029)
# Epoch [16/50], Iter [160/0] Loss: 1.8048, 2.7404, 4.5452
# tensor(0.5955)
# Epoch [16/50], Iter [180/0] Loss: 1.8068, 2.6601, 4.4670
# [16/50] Loss: 5.225
# 50000
# Accuracy of the network on the 50000 train images coarse: 46 %
# Accuracy of the network on the 50000 train images fine: 35 %
# Average Accuracy of the network on the 50000 train images: 40 %
# Accuracy of the network on the 10000 test images coarse: 40 %
# Accuracy of the network on the 10000 test images fine: 29 %
# Average Accuracy of the network on the 10000 test images: 34 %
# tensor(0.6026)
# Epoch [17/50], Iter [20/0] Loss: 1.7015, 2.5798, 4.2813
# tensor(0.6055)
# Epoch [17/50], Iter [40/0] Loss: 1.7064, 2.6189, 4.3253
# tensor(0.5897)
# Epoch [17/50], Iter [60/0] Loss: 1.6407, 2.3581, 3.9989
# tensor(0.5849)
# Epoch [17/50], Iter [80/0] Loss: 1.8286, 2.5770, 4.4056
# tensor(0.5846)
# Epoch [17/50], Iter [100/0] Loss: 1.8954, 2.6672, 4.5626
# tensor(0.5912)
# Epoch [17/50], Iter [120/0] Loss: 1.8136, 2.6230, 4.4367
# tensor(0.6047)
# Epoch [17/50], Iter [140/0] Loss: 1.7719, 2.7111, 4.4831
# tensor(0.6159)
# Epoch [17/50], Iter [160/0] Loss: 1.7380, 2.7873, 4.5253
# tensor(0.5960)
# Epoch [17/50], Iter [180/0] Loss: 1.8307, 2.7004, 4.5311
# [17/50] Loss: 5.173
# 50000
# Accuracy of the network on the 50000 train images coarse: 47 %
# Accuracy of the network on the 50000 train images fine: 36 %
# Average Accuracy of the network on the 50000 train images: 41 %
# Accuracy of the network on the 10000 test images coarse: 40 %
# Accuracy of the network on the 10000 test images fine: 29 %
# Average Accuracy of the network on the 10000 test images: 34 %
# tensor(0.6002)
# Epoch [18/50], Iter [20/0] Loss: 1.7330, 2.6021, 4.3350
# tensor(0.6029)
# Epoch [18/50], Iter [40/0] Loss: 1.6844, 2.5570, 4.2414
# tensor(0.5967)
# Epoch [18/50], Iter [60/0] Loss: 1.7617, 2.6064, 4.3680
# tensor(0.5992)
# Epoch [18/50], Iter [80/0] Loss: 1.7276, 2.5828, 4.3104
# tensor(0.5995)
# Epoch [18/50], Iter [100/0] Loss: 1.7758, 2.6581, 4.4339
# tensor(0.6065)
# Epoch [18/50], Iter [120/0] Loss: 1.5726, 2.4234, 3.9960
# tensor(0.6055)
# Epoch [18/50], Iter [140/0] Loss: 1.5176, 2.3294, 3.8470
# tensor(0.5906)
# Epoch [18/50], Iter [160/0] Loss: 1.7687, 2.5518, 4.3205
# tensor(0.6023)
# Epoch [18/50], Iter [180/0] Loss: 1.6639, 2.5195, 4.1835
# [18/50] Loss: 5.125
# 50000
# Accuracy of the network on the 50000 train images coarse: 48 %
# Accuracy of the network on the 50000 train images fine: 37 %
# Average Accuracy of the network on the 50000 train images: 42 %
# Accuracy of the network on the 10000 test images coarse: 41 %
# Accuracy of the network on the 10000 test images fine: 30 %
# Average Accuracy of the network on the 10000 test images: 35 %
# tensor(0.5943)
# Epoch [19/50], Iter [20/0] Loss: 1.6454, 2.4100, 4.0554
# tensor(0.5799)
# Epoch [19/50], Iter [40/0] Loss: 1.8716, 2.5836, 4.4551
# tensor(0.5992)
# Epoch [19/50], Iter [60/0] Loss: 1.6312, 2.4388, 4.0700
# tensor(0.5903)
# Epoch [19/50], Iter [80/0] Loss: 1.7335, 2.4976, 4.2311
# tensor(0.5905)
# Epoch [19/50], Iter [100/0] Loss: 1.6782, 2.4200, 4.0982
# tensor(0.5931)
# Epoch [19/50], Iter [120/0] Loss: 1.7452, 2.5442, 4.2894
# tensor(0.5928)
# Epoch [19/50], Iter [140/0] Loss: 1.9114, 2.7821, 4.6936
# tensor(0.6036)
# Epoch [19/50], Iter [160/0] Loss: 1.7460, 2.6587, 4.4046
# tensor(0.5934)
# Epoch [19/50], Iter [180/0] Loss: 1.7685, 2.5807, 4.3491
# [19/50] Loss: 5.079
# 50000
# Accuracy of the network on the 50000 train images coarse: 47 %
# Accuracy of the network on the 50000 train images fine: 38 %
# Average Accuracy of the network on the 50000 train images: 42 %
# Accuracy of the network on the 10000 test images coarse: 41 %
# Accuracy of the network on the 10000 test images fine: 30 %
# Average Accuracy of the network on the 10000 test images: 35 %
# tensor(0.5988)
# Epoch [20/50], Iter [20/0] Loss: 1.7249, 2.5744, 4.2993
# tensor(0.5827)
# Epoch [20/50], Iter [40/0] Loss: 1.8016, 2.5160, 4.3176
# tensor(0.5898)
# Epoch [20/50], Iter [60/0] Loss: 1.7392, 2.5009, 4.2401
# tensor(0.5940)
# Epoch [20/50], Iter [80/0] Loss: 1.7182, 2.5137, 4.2319
# tensor(0.6137)
# Epoch [20/50], Iter [100/0] Loss: 1.5369, 2.4412, 3.9781
# tensor(0.6109)
# Epoch [20/50], Iter [120/0] Loss: 1.4921, 2.3424, 3.8345
# tensor(0.5942)
# Epoch [20/50], Iter [140/0] Loss: 1.6629, 2.4349, 4.0978
# tensor(0.5935)
# Epoch [20/50], Iter [160/0] Loss: 1.6828, 2.4570, 4.1398
# tensor(0.5928)
# Epoch [20/50], Iter [180/0] Loss: 1.7248, 2.5105, 4.2352
# [20/50] Loss: 5.036
# 50000
# Accuracy of the network on the 50000 train images coarse: 48 %
# Accuracy of the network on the 50000 train images fine: 39 %
# Average Accuracy of the network on the 50000 train images: 43 %
# Accuracy of the network on the 10000 test images coarse: 41 %
# Accuracy of the network on the 10000 test images fine: 31 %
# Average Accuracy of the network on the 10000 test images: 36 %
# tensor(0.5895)
# Epoch [21/50], Iter [20/0] Loss: 1.5590, 2.2392, 3.7982
# tensor(0.5845)
# Epoch [21/50], Iter [40/0] Loss: 1.6974, 2.3873, 4.0848
# tensor(0.5939)
# Epoch [21/50], Iter [60/0] Loss: 1.7863, 2.6127, 4.3991
# tensor(0.5895)
# Epoch [21/50], Iter [80/0] Loss: 1.8196, 2.6127, 4.4323
# tensor(0.6036)
# Epoch [21/50], Iter [100/0] Loss: 1.6955, 2.5818, 4.2773
# tensor(0.5924)
# Epoch [21/50], Iter [120/0] Loss: 1.5204, 2.2098, 3.7301
# tensor(0.5781)
# Epoch [21/50], Iter [140/0] Loss: 1.7631, 2.4160, 4.1791
# tensor(0.5954)
# Epoch [21/50], Iter [160/0] Loss: 1.7156, 2.5246, 4.2403
# tensor(0.5884)
# Epoch [21/50], Iter [180/0] Loss: 1.7916, 2.5609, 4.3525
# [21/50] Loss: 4.994
# 50000
# Accuracy of the network on the 50000 train images coarse: 48 %
# Accuracy of the network on the 50000 train images fine: 39 %
# Average Accuracy of the network on the 50000 train images: 43 %
# Accuracy of the network on the 10000 test images coarse: 41 %
# Accuracy of the network on the 10000 test images fine: 30 %
# Average Accuracy of the network on the 10000 test images: 35 %
# tensor(0.5776)
# Epoch [22/50], Iter [20/0] Loss: 1.6390, 2.2410, 3.8799
# tensor(0.6009)
# Epoch [22/50], Iter [40/0] Loss: 1.6082, 2.4217, 4.0298
# tensor(0.6071)
# Epoch [22/50], Iter [60/0] Loss: 1.4476, 2.2370, 3.6845
# tensor(0.5865)
# Epoch [22/50], Iter [80/0] Loss: 1.8369, 2.6054, 4.4423
# tensor(0.5949)
# Epoch [22/50], Iter [100/0] Loss: 1.5410, 2.2630, 3.8040
# tensor(0.6055)
# Epoch [22/50], Iter [120/0] Loss: 1.6631, 2.5522, 4.2153
# tensor(0.5817)
# Epoch [22/50], Iter [140/0] Loss: 1.7113, 2.3793, 4.0906
# tensor(0.5959)
# Epoch [22/50], Iter [160/0] Loss: 1.6525, 2.4370, 4.0895
# tensor(0.5931)
# Epoch [22/50], Iter [180/0] Loss: 1.6849, 2.4562, 4.1412
# [22/50] Loss: 4.954
# 50000
# Accuracy of the network on the 50000 train images coarse: 49 %
# Accuracy of the network on the 50000 train images fine: 39 %
# Average Accuracy of the network on the 50000 train images: 44 %
# Accuracy of the network on the 10000 test images coarse: 41 %
# Accuracy of the network on the 10000 test images fine: 31 %
# Average Accuracy of the network on the 10000 test images: 36 %
# tensor(0.5953)
# Epoch [23/50], Iter [20/0] Loss: 1.6064, 2.3629, 3.9693
# tensor(0.5817)
# Epoch [23/50], Iter [40/0] Loss: 1.6075, 2.2352, 3.8427
# tensor(0.5925)
# Epoch [23/50], Iter [60/0] Loss: 1.6629, 2.4180, 4.0809
# tensor(0.5824)
# Epoch [23/50], Iter [80/0] Loss: 1.6791, 2.3419, 4.0210
# tensor(0.6052)
# Epoch [23/50], Iter [100/0] Loss: 1.5768, 2.4172, 3.9940
# tensor(0.5893)
# Epoch [23/50], Iter [120/0] Loss: 1.5896, 2.2811, 3.8707
# tensor(0.5809)
# Epoch [23/50], Iter [140/0] Loss: 1.7629, 2.4434, 4.2063
# tensor(0.6005)
# Epoch [23/50], Iter [160/0] Loss: 1.6448, 2.4722, 4.1170
# tensor(0.5983)
# Epoch [23/50], Iter [180/0] Loss: 1.5625, 2.3276, 3.8901
# [23/50] Loss: 4.916
# 50000
# Accuracy of the network on the 50000 train images coarse: 50 %
# Accuracy of the network on the 50000 train images fine: 40 %
# Average Accuracy of the network on the 50000 train images: 45 %
# Accuracy of the network on the 10000 test images coarse: 41 %
# Accuracy of the network on the 10000 test images fine: 30 %
# Average Accuracy of the network on the 10000 test images: 35 %
# tensor(0.5992)
# Epoch [24/50], Iter [20/0] Loss: 1.5947, 2.3836, 3.9784
# tensor(0.5921)
# Epoch [24/50], Iter [40/0] Loss: 1.6969, 2.4629, 4.1597
# tensor(0.6057)
# Epoch [24/50], Iter [60/0] Loss: 1.5890, 2.4411, 4.0301
# tensor(0.6052)
# Epoch [24/50], Iter [80/0] Loss: 1.4472, 2.2181, 3.6653
# tensor(0.6086)
# Epoch [24/50], Iter [100/0] Loss: 1.4698, 2.2854, 3.7552
# tensor(0.5938)
# Epoch [24/50], Iter [120/0] Loss: 1.5360, 2.2455, 3.7815
# tensor(0.6028)
# Epoch [24/50], Iter [140/0] Loss: 1.4358, 2.1794, 3.6152
# tensor(0.5903)
# Epoch [24/50], Iter [160/0] Loss: 1.6971, 2.4448, 4.1419
# tensor(0.5938)
# Epoch [24/50], Iter [180/0] Loss: 1.7013, 2.4873, 4.1887
# [24/50] Loss: 4.879
# 50000
# Accuracy of the network on the 50000 train images coarse: 50 %
# Accuracy of the network on the 50000 train images fine: 41 %
# Average Accuracy of the network on the 50000 train images: 45 %
# Accuracy of the network on the 10000 test images coarse: 42 %
# Accuracy of the network on the 10000 test images fine: 31 %
# Average Accuracy of the network on the 10000 test images: 36 %
# tensor(0.6003)
# Epoch [25/50], Iter [20/0] Loss: 1.5104, 2.2683, 3.7787
# tensor(0.6003)
# Epoch [25/50], Iter [40/0] Loss: 1.5752, 2.3658, 3.9410
# tensor(0.5873)
# Epoch [25/50], Iter [60/0] Loss: 1.5878, 2.2591, 3.8469
# tensor(0.6073)
# Epoch [25/50], Iter [80/0] Loss: 1.3716, 2.1208, 3.4924
# tensor(0.5933)
# Epoch [25/50], Iter [100/0] Loss: 1.5208, 2.2182, 3.7390
# tensor(0.5831)
# Epoch [25/50], Iter [120/0] Loss: 1.6954, 2.3715, 4.0669
# tensor(0.5764)
# Epoch [25/50], Iter [140/0] Loss: 1.7495, 2.3807, 4.1302
# tensor(0.5842)
# Epoch [25/50], Iter [160/0] Loss: 1.6078, 2.2594, 3.8673
# tensor(0.5907)
# Epoch [25/50], Iter [180/0] Loss: 1.6241, 2.3439, 3.9680
# [25/50] Loss: 4.844
# 50000
# Accuracy of the network on the 50000 train images coarse: 50 %
# Accuracy of the network on the 50000 train images fine: 41 %
# Average Accuracy of the network on the 50000 train images: 45 %
# Accuracy of the network on the 10000 test images coarse: 42 %
# Accuracy of the network on the 10000 test images fine: 31 %
# Average Accuracy of the network on the 10000 test images: 36 %
# tensor(0.6005)
# Epoch [26/50], Iter [20/0] Loss: 1.6084, 2.4176, 4.0260
# tensor(0.6076)
# Epoch [26/50], Iter [40/0] Loss: 1.6358, 2.5334, 4.1692
# tensor(0.5911)
# Epoch [26/50], Iter [60/0] Loss: 1.6242, 2.3478, 3.9721
# tensor(0.6050)
# Epoch [26/50], Iter [80/0] Loss: 1.4944, 2.2886, 3.7830
# tensor(0.5862)
# Epoch [26/50], Iter [100/0] Loss: 1.6157, 2.2886, 3.9043
# tensor(0.6011)
# Epoch [26/50], Iter [120/0] Loss: 1.5417, 2.3227, 3.8644
# tensor(0.5819)
# Epoch [26/50], Iter [140/0] Loss: 1.5988, 2.2253, 3.8241
# tensor(0.6003)
# Epoch [26/50], Iter [160/0] Loss: 1.6087, 2.4159, 4.0246
# tensor(0.5788)
# Epoch [26/50], Iter [180/0] Loss: 1.6547, 2.2736, 3.9283
# [26/50] Loss: 4.809
# 50000
# Accuracy of the network on the 50000 train images coarse: 51 %
# Accuracy of the network on the 50000 train images fine: 41 %
# Average Accuracy of the network on the 50000 train images: 46 %
# Accuracy of the network on the 10000 test images coarse: 41 %
# Accuracy of the network on the 10000 test images fine: 31 %
# Average Accuracy of the network on the 10000 test images: 36 %
# tensor(0.5908)
# Epoch [27/50], Iter [20/0] Loss: 1.5949, 2.3023, 3.8972
# tensor(0.5985)
# Epoch [27/50], Iter [40/0] Loss: 1.6392, 2.4432, 4.0824
# tensor(0.5830)
# Epoch [27/50], Iter [60/0] Loss: 1.6567, 2.3162, 3.9729
# tensor(0.5842)
# Epoch [27/50], Iter [80/0] Loss: 1.7464, 2.4538, 4.2002
# tensor(0.5912)
# Epoch [27/50], Iter [100/0] Loss: 1.6385, 2.3700, 4.0085
# tensor(0.6055)
# Epoch [27/50], Iter [120/0] Loss: 1.5697, 2.4095, 3.9792
# tensor(0.6086)
# Epoch [27/50], Iter [140/0] Loss: 1.5635, 2.4308, 3.9942
# tensor(0.5968)
# Epoch [27/50], Iter [160/0] Loss: 1.6363, 2.4220, 4.0583
# tensor(0.5877)
# Epoch [27/50], Iter [180/0] Loss: 1.5644, 2.2300, 3.7944
# [27/50] Loss: 4.776
# 50000
# Accuracy of the network on the 50000 train images coarse: 51 %
# Accuracy of the network on the 50000 train images fine: 42 %
# Average Accuracy of the network on the 50000 train images: 46 %
# Accuracy of the network on the 10000 test images coarse: 41 %
# Accuracy of the network on the 10000 test images fine: 31 %
# Average Accuracy of the network on the 10000 test images: 36 %
# tensor(0.5943)
# Epoch [28/50], Iter [20/0] Loss: 1.4848, 2.1746, 3.6593
# tensor(0.5864)
# Epoch [28/50], Iter [40/0] Loss: 1.6963, 2.4048, 4.1012
# tensor(0.6052)
# Epoch [28/50], Iter [60/0] Loss: 1.4886, 2.2819, 3.7705
# tensor(0.5913)
# Epoch [28/50], Iter [80/0] Loss: 1.6857, 2.4390, 4.1247
# tensor(0.5903)
# Epoch [28/50], Iter [100/0] Loss: 1.4931, 2.1515, 3.6446
# tensor(0.5736)
# Epoch [28/50], Iter [120/0] Loss: 1.6865, 2.2690, 3.9556
# tensor(0.5762)
# Epoch [28/50], Iter [140/0] Loss: 1.6078, 2.1856, 3.7934
# tensor(0.5932)
# Epoch [28/50], Iter [160/0] Loss: 1.5495, 2.2593, 3.8089
# tensor(0.6012)
# Epoch [28/50], Iter [180/0] Loss: 1.6160, 2.4358, 4.0519
# [28/50] Loss: 4.744
# 50000
# Accuracy of the network on the 50000 train images coarse: 52 %
# Accuracy of the network on the 50000 train images fine: 43 %
# Average Accuracy of the network on the 50000 train images: 47 %
# Accuracy of the network on the 10000 test images coarse: 42 %
# Accuracy of the network on the 10000 test images fine: 31 %
# Average Accuracy of the network on the 10000 test images: 36 %
# tensor(0.6013)
# Epoch [29/50], Iter [20/0] Loss: 1.3282, 2.0030, 3.3313
# tensor(0.5863)
# Epoch [29/50], Iter [40/0] Loss: 1.5504, 2.1973, 3.7477
# tensor(0.6018)
# Epoch [29/50], Iter [60/0] Loss: 1.5322, 2.3153, 3.8475
# tensor(0.5890)
# Epoch [29/50], Iter [80/0] Loss: 1.5008, 2.1508, 3.6516
# tensor(0.5960)
# Epoch [29/50], Iter [100/0] Loss: 1.5857, 2.3397, 3.9255
# tensor(0.5853)
# Epoch [29/50], Iter [120/0] Loss: 1.6664, 2.3514, 4.0178
# tensor(0.6014)
# Epoch [29/50], Iter [140/0] Loss: 1.4520, 2.1909, 3.6429
# tensor(0.5930)
# Epoch [29/50], Iter [160/0] Loss: 1.6422, 2.3930, 4.0353
# tensor(0.5968)
# Epoch [29/50], Iter [180/0] Loss: 1.5474, 2.2908, 3.8382
# [29/50] Loss: 4.713
# 50000
# Accuracy of the network on the 50000 train images coarse: 53 %
# Accuracy of the network on the 50000 train images fine: 43 %
# Average Accuracy of the network on the 50000 train images: 48 %
# Accuracy of the network on the 10000 test images coarse: 41 %
# Accuracy of the network on the 10000 test images fine: 32 %
# Average Accuracy of the network on the 10000 test images: 36 %
# tensor(0.6101)
# Epoch [30/50], Iter [20/0] Loss: 1.3899, 2.1746, 3.5645
# tensor(0.5915)
# Epoch [30/50], Iter [40/0] Loss: 1.5679, 2.2706, 3.8385
# tensor(0.5719)
# Epoch [30/50], Iter [60/0] Loss: 1.6186, 2.1622, 3.7808
# tensor(0.5928)
# Epoch [30/50], Iter [80/0] Loss: 1.4225, 2.0707, 3.4932
# tensor(0.5924)
# Epoch [30/50], Iter [100/0] Loss: 1.5361, 2.2321, 3.7681
# tensor(0.5798)
# Epoch [30/50], Iter [120/0] Loss: 1.5805, 2.1812, 3.7617
# tensor(0.5873)
# Epoch [30/50], Iter [140/0] Loss: 1.5922, 2.2656, 3.8578
# tensor(0.6008)
# Epoch [30/50], Iter [160/0] Loss: 1.6760, 2.5224, 4.1983
# tensor(0.5783)
# Epoch [30/50], Iter [180/0] Loss: 1.5858, 2.1745, 3.7603
# [30/50] Loss: 4.683
# 50000
# Accuracy of the network on the 50000 train images coarse: 53 %
# Accuracy of the network on the 50000 train images fine: 44 %
# Average Accuracy of the network on the 50000 train images: 48 %
# Accuracy of the network on the 10000 test images coarse: 42 %
# Accuracy of the network on the 10000 test images fine: 32 %
# Average Accuracy of the network on the 10000 test images: 37 %
# tensor(0.5742)
# Epoch [31/50], Iter [20/0] Loss: 1.5867, 2.1395, 3.7262
# tensor(0.5929)
# Epoch [31/50], Iter [40/0] Loss: 1.5010, 2.1861, 3.6871
# tensor(0.5880)
# Epoch [31/50], Iter [60/0] Loss: 1.4100, 2.0120, 3.4221
# tensor(0.5880)
# Epoch [31/50], Iter [80/0] Loss: 1.6049, 2.2902, 3.8950
# tensor(0.5881)
# Epoch [31/50], Iter [100/0] Loss: 1.5788, 2.2538, 3.8326
# tensor(0.5877)
# Epoch [31/50], Iter [120/0] Loss: 1.6424, 2.3414, 3.9838
# tensor(0.5847)
# Epoch [31/50], Iter [140/0] Loss: 1.5879, 2.2354, 3.8234
# tensor(0.5943)
# Epoch [31/50], Iter [160/0] Loss: 1.5509, 2.2716, 3.8224
# tensor(0.5986)
# Epoch [31/50], Iter [180/0] Loss: 1.5741, 2.3477, 3.9219
# [31/50] Loss: 4.653
# 50000
# Accuracy of the network on the 50000 train images coarse: 53 %
# Accuracy of the network on the 50000 train images fine: 44 %
# Average Accuracy of the network on the 50000 train images: 48 %
# Accuracy of the network on the 10000 test images coarse: 42 %
# Accuracy of the network on the 10000 test images fine: 32 %
# Average Accuracy of the network on the 10000 test images: 37 %
# tensor(0.6110)
# Epoch [32/50], Iter [20/0] Loss: 1.3158, 2.0668, 3.3826
# tensor(0.6025)
# Epoch [32/50], Iter [40/0] Loss: 1.4098, 2.1369, 3.5467
# tensor(0.5875)
# Epoch [32/50], Iter [60/0] Loss: 1.6312, 2.3231, 3.9543
# tensor(0.5935)
# Epoch [32/50], Iter [80/0] Loss: 1.6044, 2.3426, 3.9470
# tensor(0.5903)
# Epoch [32/50], Iter [100/0] Loss: 1.6322, 2.3519, 3.9841
# tensor(0.5888)
# Epoch [32/50], Iter [120/0] Loss: 1.5352, 2.1985, 3.7337
# tensor(0.6011)
# Epoch [32/50], Iter [140/0] Loss: 1.5373, 2.3167, 3.8540
# tensor(0.5857)
# Epoch [32/50], Iter [160/0] Loss: 1.4372, 2.0320, 3.4692
# tensor(0.5894)
# Epoch [32/50], Iter [180/0] Loss: 1.5708, 2.2550, 3.8258
# [32/50] Loss: 4.625
# 50000
# Accuracy of the network on the 50000 train images coarse: 54 %
# Accuracy of the network on the 50000 train images fine: 45 %
# Average Accuracy of the network on the 50000 train images: 49 %
# Accuracy of the network on the 10000 test images coarse: 42 %
# Accuracy of the network on the 10000 test images fine: 32 %
# Average Accuracy of the network on the 10000 test images: 37 %
# tensor(0.5886)
# Epoch [33/50], Iter [20/0] Loss: 1.4509, 2.0757, 3.5266
# tensor(0.5968)
# Epoch [33/50], Iter [40/0] Loss: 1.4643, 2.1672, 3.6315
# tensor(0.5900)
# Epoch [33/50], Iter [60/0] Loss: 1.5304, 2.2025, 3.7329
# tensor(0.5967)
# Epoch [33/50], Iter [80/0] Loss: 1.4800, 2.1894, 3.6694
# tensor(0.5769)
# Epoch [33/50], Iter [100/0] Loss: 1.5557, 2.1215, 3.6772
# tensor(0.5878)
# Epoch [33/50], Iter [120/0] Loss: 1.5006, 2.1397, 3.6402
# tensor(0.6035)
# Epoch [33/50], Iter [140/0] Loss: 1.5435, 2.3496, 3.8930
# tensor(0.5776)
# Epoch [33/50], Iter [160/0] Loss: 1.5590, 2.1318, 3.6908
# tensor(0.5881)
# Epoch [33/50], Iter [180/0] Loss: 1.5437, 2.2039, 3.7476
# [33/50] Loss: 4.597
# 50000
# Accuracy of the network on the 50000 train images coarse: 54 %
# Accuracy of the network on the 50000 train images fine: 46 %
# Average Accuracy of the network on the 50000 train images: 50 %
# Accuracy of the network on the 10000 test images coarse: 42 %
# Accuracy of the network on the 10000 test images fine: 33 %
# Average Accuracy of the network on the 10000 test images: 37 %
# tensor(0.5858)
# Epoch [34/50], Iter [20/0] Loss: 1.4713, 2.0805, 3.5518
# tensor(0.5873)
# Epoch [34/50], Iter [40/0] Loss: 1.5268, 2.1728, 3.6996
# tensor(0.5837)
# Epoch [34/50], Iter [60/0] Loss: 1.5195, 2.1303, 3.6498
# tensor(0.5833)
# Epoch [34/50], Iter [80/0] Loss: 1.4321, 2.0045, 3.4366
# tensor(0.5954)
# Epoch [34/50], Iter [100/0] Loss: 1.5085, 2.2199, 3.7284
# tensor(0.5851)
# Epoch [34/50], Iter [120/0] Loss: 1.6344, 2.3047, 3.9391
# tensor(0.5844)
# Epoch [34/50], Iter [140/0] Loss: 1.6611, 2.3356, 3.9966
# tensor(0.5953)
# Epoch [34/50], Iter [160/0] Loss: 1.4575, 2.1443, 3.6019
# tensor(0.5889)
# Epoch [34/50], Iter [180/0] Loss: 1.5118, 2.1653, 3.6771
# [34/50] Loss: 4.570
# 50000
# Accuracy of the network on the 50000 train images coarse: 54 %
# Accuracy of the network on the 50000 train images fine: 45 %
# Average Accuracy of the network on the 50000 train images: 49 %
# Accuracy of the network on the 10000 test images coarse: 42 %
# Accuracy of the network on the 10000 test images fine: 32 %
# Average Accuracy of the network on the 10000 test images: 37 %
# tensor(0.6040)
# Epoch [35/50], Iter [20/0] Loss: 1.4721, 2.2455, 3.7176
# tensor(0.5817)
# Epoch [35/50], Iter [40/0] Loss: 1.3982, 1.9444, 3.3425
# tensor(0.5824)
# Epoch [35/50], Iter [60/0] Loss: 1.5489, 2.1603, 3.7093
# tensor(0.5962)
# Epoch [35/50], Iter [80/0] Loss: 1.4945, 2.2071, 3.7016
# tensor(0.5975)
# Epoch [35/50], Iter [100/0] Loss: 1.3982, 2.0753, 3.4735
# tensor(0.5873)
# Epoch [35/50], Iter [120/0] Loss: 1.5427, 2.1951, 3.7378
# tensor(0.5771)
# Epoch [35/50], Iter [140/0] Loss: 1.7505, 2.3884, 4.1389
# tensor(0.5958)
# Epoch [35/50], Iter [160/0] Loss: 1.5193, 2.2391, 3.7584
# tensor(0.5809)
# Epoch [35/50], Iter [180/0] Loss: 1.5513, 2.1505, 3.7017
# [35/50] Loss: 4.543
# 50000
# Accuracy of the network on the 50000 train images coarse: 55 %
# Accuracy of the network on the 50000 train images fine: 46 %
# Average Accuracy of the network on the 50000 train images: 50 %
# Accuracy of the network on the 10000 test images coarse: 42 %
# Accuracy of the network on the 10000 test images fine: 32 %
# Average Accuracy of the network on the 10000 test images: 37 %
# tensor(0.5925)
# Epoch [36/50], Iter [20/0] Loss: 1.5529, 2.2577, 3.8106
# tensor(0.5850)
# Epoch [36/50], Iter [40/0] Loss: 1.4898, 2.1000, 3.5898
# tensor(0.5764)
# Epoch [36/50], Iter [60/0] Loss: 1.6344, 2.2240, 3.8584
# tensor(0.5873)
# Epoch [36/50], Iter [80/0] Loss: 1.4317, 2.0371, 3.4688
# tensor(0.5995)
# Epoch [36/50], Iter [100/0] Loss: 1.4130, 2.1153, 3.5282
# tensor(0.5743)
# Epoch [36/50], Iter [120/0] Loss: 1.4967, 2.0191, 3.5158
# tensor(0.5807)
# Epoch [36/50], Iter [140/0] Loss: 1.5439, 2.1383, 3.6822
# tensor(0.5883)
# Epoch [36/50], Iter [160/0] Loss: 1.6585, 2.3701, 4.0286
# tensor(0.5947)
# Epoch [36/50], Iter [180/0] Loss: 1.4635, 2.1477, 3.6112
# [36/50] Loss: 4.517
# 50000
# Accuracy of the network on the 50000 train images coarse: 55 %
# Accuracy of the network on the 50000 train images fine: 46 %
# Average Accuracy of the network on the 50000 train images: 50 %
# Accuracy of the network on the 10000 test images coarse: 42 %
# Accuracy of the network on the 10000 test images fine: 32 %
# Average Accuracy of the network on the 10000 test images: 37 %
# tensor(0.5971)
# Epoch [37/50], Iter [20/0] Loss: 1.4282, 2.1162, 3.5445
# tensor(0.5917)
# Epoch [37/50], Iter [40/0] Loss: 1.4078, 2.0400, 3.4478
# tensor(0.5979)
# Epoch [37/50], Iter [60/0] Loss: 1.3372, 1.9885, 3.3257
# tensor(0.6115)
# Epoch [37/50], Iter [80/0] Loss: 1.2765, 2.0095, 3.2860
# tensor(0.5988)
# Epoch [37/50], Iter [100/0] Loss: 1.3882, 2.0720, 3.4603
# tensor(0.5735)
# Epoch [37/50], Iter [120/0] Loss: 1.5259, 2.0516, 3.5776
# tensor(0.5695)
# Epoch [37/50], Iter [140/0] Loss: 1.6431, 2.1738, 3.8169
# tensor(0.5989)
# Epoch [37/50], Iter [160/0] Loss: 1.4039, 2.0963, 3.5002
# tensor(0.5990)
# Epoch [37/50], Iter [180/0] Loss: 1.3869, 2.0720, 3.4589
# [37/50] Loss: 4.492
# 50000
# Accuracy of the network on the 50000 train images coarse: 55 %
# Accuracy of the network on the 50000 train images fine: 47 %
# Average Accuracy of the network on the 50000 train images: 51 %
# Accuracy of the network on the 10000 test images coarse: 42 %
# Accuracy of the network on the 10000 test images fine: 32 %
# Average Accuracy of the network on the 10000 test images: 37 %
# tensor(0.6124)
# Epoch [38/50], Iter [20/0] Loss: 1.2163, 1.9215, 3.1379
# tensor(0.5916)
# Epoch [38/50], Iter [40/0] Loss: 1.3916, 2.0155, 3.4071
# tensor(0.5695)
# Epoch [38/50], Iter [60/0] Loss: 1.5662, 2.0723, 3.6386
# tensor(0.6031)
# Epoch [38/50], Iter [80/0] Loss: 1.3992, 2.1266, 3.5258
# tensor(0.6153)
# Epoch [38/50], Iter [100/0] Loss: 1.2891, 2.0622, 3.3513
# tensor(0.5944)
# Epoch [38/50], Iter [120/0] Loss: 1.4263, 2.0901, 3.5164
# tensor(0.5995)
# Epoch [38/50], Iter [140/0] Loss: 1.4967, 2.2400, 3.7367
# tensor(0.5939)
# Epoch [38/50], Iter [160/0] Loss: 1.3926, 2.0365, 3.4291
# tensor(0.6014)
# Epoch [38/50], Iter [180/0] Loss: 1.4088, 2.1254, 3.5342
# [38/50] Loss: 4.467
# 50000
# Accuracy of the network on the 50000 train images coarse: 55 %
# Accuracy of the network on the 50000 train images fine: 47 %
# Average Accuracy of the network on the 50000 train images: 51 %
# Accuracy of the network on the 10000 test images coarse: 42 %
# Accuracy of the network on the 10000 test images fine: 32 %
# Average Accuracy of the network on the 10000 test images: 37 %
# tensor(0.5766)
# Epoch [39/50], Iter [20/0] Loss: 1.3708, 1.8669, 3.2377
# tensor(0.5878)
# Epoch [39/50], Iter [40/0] Loss: 1.4200, 2.0252, 3.4452
# tensor(0.6013)
# Epoch [39/50], Iter [60/0] Loss: 1.3468, 2.0311, 3.3778
# tensor(0.5957)
# Epoch [39/50], Iter [80/0] Loss: 1.4425, 2.1253, 3.5679
# tensor(0.6000)
# Epoch [39/50], Iter [100/0] Loss: 1.4252, 2.1382, 3.5634
# tensor(0.5899)
# Epoch [39/50], Iter [120/0] Loss: 1.3653, 1.9641, 3.3294
# tensor(0.6008)
# Epoch [39/50], Iter [140/0] Loss: 1.4304, 2.1523, 3.5827
# tensor(0.6073)
# Epoch [39/50], Iter [160/0] Loss: 1.4734, 2.2785, 3.7518
# tensor(0.5808)
# Epoch [39/50], Iter [180/0] Loss: 1.5120, 2.0951, 3.6072
# [39/50] Loss: 4.443
# 50000
# Accuracy of the network on the 50000 train images coarse: 56 %
# Accuracy of the network on the 50000 train images fine: 48 %
# Average Accuracy of the network on the 50000 train images: 52 %
# Accuracy of the network on the 10000 test images coarse: 42 %
# Accuracy of the network on the 10000 test images fine: 32 %
# Average Accuracy of the network on the 10000 test images: 37 %
# tensor(0.5933)
# Epoch [40/50], Iter [20/0] Loss: 1.4709, 2.1454, 3.6163
# tensor(0.5746)
# Epoch [40/50], Iter [40/0] Loss: 1.4691, 1.9840, 3.4531
# tensor(0.5995)
# Epoch [40/50], Iter [60/0] Loss: 1.4654, 2.1936, 3.6590
# tensor(0.5862)
# Epoch [40/50], Iter [80/0] Loss: 1.5088, 2.1372, 3.6460
# tensor(0.5703)
# Epoch [40/50], Iter [100/0] Loss: 1.6966, 2.2520, 3.9486
# tensor(0.5991)
# Epoch [40/50], Iter [120/0] Loss: 1.4197, 2.1219, 3.5417
# tensor(0.5880)
# Epoch [40/50], Iter [140/0] Loss: 1.4071, 2.0082, 3.4153
# tensor(0.5929)
# Epoch [40/50], Iter [160/0] Loss: 1.4909, 2.1717, 3.6626
# tensor(0.5766)
# Epoch [40/50], Iter [180/0] Loss: 1.5519, 2.1134, 3.6653
# [40/50] Loss: 4.420
# 50000
# Accuracy of the network on the 50000 train images coarse: 55 %
# Accuracy of the network on the 50000 train images fine: 48 %
# Average Accuracy of the network on the 50000 train images: 51 %
# Accuracy of the network on the 10000 test images coarse: 42 %
# Accuracy of the network on the 10000 test images fine: 32 %
# Average Accuracy of the network on the 10000 test images: 37 %
# tensor(0.6014)
# Epoch [41/50], Iter [20/0] Loss: 1.3929, 2.1019, 3.4948
# tensor(0.6016)
# Epoch [41/50], Iter [40/0] Loss: 1.2406, 1.8732, 3.1138
# tensor(0.5873)
# Epoch [41/50], Iter [60/0] Loss: 1.3231, 1.8830, 3.2061
# tensor(0.5961)
# Epoch [41/50], Iter [80/0] Loss: 1.3872, 2.0473, 3.4346
# tensor(0.5833)
# Epoch [41/50], Iter [100/0] Loss: 1.5273, 2.1376, 3.6649
# tensor(0.5906)
# Epoch [41/50], Iter [120/0] Loss: 1.5162, 2.1875, 3.7037
# tensor(0.6011)
# Epoch [41/50], Iter [140/0] Loss: 1.3066, 1.9691, 3.2758
# tensor(0.5874)
# Epoch [41/50], Iter [160/0] Loss: 1.5217, 2.1664, 3.6881
# tensor(0.5811)
# Epoch [41/50], Iter [180/0] Loss: 1.4839, 2.0583, 3.5422
# [41/50] Loss: 4.397
# 50000
# Accuracy of the network on the 50000 train images coarse: 57 %
# Accuracy of the network on the 50000 train images fine: 48 %
# Average Accuracy of the network on the 50000 train images: 52 %
# Accuracy of the network on the 10000 test images coarse: 42 %
# Accuracy of the network on the 10000 test images fine: 32 %
# Average Accuracy of the network on the 10000 test images: 37 %
# tensor(0.5992)
# Epoch [42/50], Iter [20/0] Loss: 1.3907, 2.0792, 3.4699
# tensor(0.5925)
# Epoch [42/50], Iter [40/0] Loss: 1.3474, 1.9593, 3.3067
# tensor(0.5871)
# Epoch [42/50], Iter [60/0] Loss: 1.3948, 1.9833, 3.3781
# tensor(0.5731)
# Epoch [42/50], Iter [80/0] Loss: 1.3333, 1.7897, 3.1231
# tensor(0.5741)
# Epoch [42/50], Iter [100/0] Loss: 1.3875, 1.8706, 3.2581
# tensor(0.5856)
# Epoch [42/50], Iter [120/0] Loss: 1.4884, 2.1034, 3.5918
# tensor(0.5802)
# Epoch [42/50], Iter [140/0] Loss: 1.5682, 2.1678, 3.7361
# tensor(0.5777)
# Epoch [42/50], Iter [160/0] Loss: 1.4402, 1.9699, 3.4101
# tensor(0.5841)
# Epoch [42/50], Iter [180/0] Loss: 1.5307, 2.1499, 3.6806
# [42/50] Loss: 4.375
# 50000
# Accuracy of the network on the 50000 train images coarse: 57 %
# Accuracy of the network on the 50000 train images fine: 50 %
# Average Accuracy of the network on the 50000 train images: 53 %
# Accuracy of the network on the 10000 test images coarse: 42 %
# Accuracy of the network on the 10000 test images fine: 33 %
# Average Accuracy of the network on the 10000 test images: 37 %
# tensor(0.5737)
# Epoch [43/50], Iter [20/0] Loss: 1.3866, 1.8659, 3.2525
# tensor(0.6005)
# Epoch [43/50], Iter [40/0] Loss: 1.3010, 1.9559, 3.2569
# tensor(0.5751)
# Epoch [43/50], Iter [60/0] Loss: 1.4673, 1.9857, 3.4530
# tensor(0.5874)
# Epoch [43/50], Iter [80/0] Loss: 1.3609, 1.9371, 3.2980
# tensor(0.5755)
# Epoch [43/50], Iter [100/0] Loss: 1.3974, 1.8945, 3.2919
# tensor(0.5966)
# Epoch [43/50], Iter [120/0] Loss: 1.5037, 2.2243, 3.7280
# tensor(0.6010)
# Epoch [43/50], Iter [140/0] Loss: 1.4487, 2.1818, 3.6306
# tensor(0.6020)
# Epoch [43/50], Iter [160/0] Loss: 1.3036, 1.9717, 3.2752
# tensor(0.5893)
# Epoch [43/50], Iter [180/0] Loss: 1.3794, 1.9791, 3.3585
# [43/50] Loss: 4.353
# 50000
# Accuracy of the network on the 50000 train images coarse: 57 %
# Accuracy of the network on the 50000 train images fine: 48 %
# Average Accuracy of the network on the 50000 train images: 52 %
# Accuracy of the network on the 10000 test images coarse: 42 %
# Accuracy of the network on the 10000 test images fine: 32 %
# Average Accuracy of the network on the 10000 test images: 37 %
# tensor(0.5901)
# Epoch [44/50], Iter [20/0] Loss: 1.4248, 2.0510, 3.4758
# tensor(0.6118)
# Epoch [44/50], Iter [40/0] Loss: 1.2362, 1.9479, 3.1841
# tensor(0.5862)
# Epoch [44/50], Iter [60/0] Loss: 1.3288, 1.8827, 3.2115
# tensor(0.5870)
# Epoch [44/50], Iter [80/0] Loss: 1.3213, 1.8782, 3.1995
# tensor(0.5650)
# Epoch [44/50], Iter [100/0] Loss: 1.5520, 2.0157, 3.5677
# tensor(0.5668)
# Epoch [44/50], Iter [120/0] Loss: 1.5180, 1.9865, 3.5045
# tensor(0.5877)
# Epoch [44/50], Iter [140/0] Loss: 1.4000, 1.9958, 3.3959
# tensor(0.5777)
# Epoch [44/50], Iter [160/0] Loss: 1.5394, 2.1062, 3.6456
# tensor(0.5766)
# Epoch [44/50], Iter [180/0] Loss: 1.6314, 2.2221, 3.8534
# [44/50] Loss: 4.331
# 50000
# Accuracy of the network on the 50000 train images coarse: 56 %
# Accuracy of the network on the 50000 train images fine: 49 %
# Average Accuracy of the network on the 50000 train images: 52 %
# Accuracy of the network on the 10000 test images coarse: 42 %
# Accuracy of the network on the 10000 test images fine: 32 %
# Average Accuracy of the network on the 10000 test images: 37 %
# tensor(0.5901)
# Epoch [45/50], Iter [20/0] Loss: 1.3727, 1.9764, 3.3491
# tensor(0.5895)
# Epoch [45/50], Iter [40/0] Loss: 1.2938, 1.8583, 3.1521
# tensor(0.5909)
# Epoch [45/50], Iter [60/0] Loss: 1.3075, 1.8884, 3.1958
# tensor(0.5780)
# Epoch [45/50], Iter [80/0] Loss: 1.5014, 2.0561, 3.5575
# tensor(0.5829)
# Epoch [45/50], Iter [100/0] Loss: 1.3847, 1.9354, 3.3201
# tensor(0.5903)
# Epoch [45/50], Iter [120/0] Loss: 1.3101, 1.8875, 3.1976
# tensor(0.5925)
# Epoch [45/50], Iter [140/0] Loss: 1.3826, 2.0104, 3.3930
# tensor(0.5961)
# Epoch [45/50], Iter [160/0] Loss: 1.4286, 2.1080, 3.5366
# tensor(0.5789)
# Epoch [45/50], Iter [180/0] Loss: 1.4156, 1.9463, 3.3619
# [45/50] Loss: 4.310
# 50000
# Accuracy of the network on the 50000 train images coarse: 58 %
# Accuracy of the network on the 50000 train images fine: 50 %
# Average Accuracy of the network on the 50000 train images: 54 %
# Accuracy of the network on the 10000 test images coarse: 42 %
# Accuracy of the network on the 10000 test images fine: 32 %
# Average Accuracy of the network on the 10000 test images: 37 %
# tensor(0.5925)
# Epoch [46/50], Iter [20/0] Loss: 1.3942, 2.0275, 3.4217
# tensor(0.5854)
# Epoch [46/50], Iter [40/0] Loss: 1.2819, 1.8101, 3.0920
# tensor(0.5810)
# Epoch [46/50], Iter [60/0] Loss: 1.5245, 2.1141, 3.6387
# tensor(0.5993)
# Epoch [46/50], Iter [80/0] Loss: 1.2525, 1.8732, 3.1257
# tensor(0.5826)
# Epoch [46/50], Iter [100/0] Loss: 1.4377, 2.0067, 3.4444
# tensor(0.5838)
# Epoch [46/50], Iter [120/0] Loss: 1.4624, 2.0516, 3.5140
# tensor(0.5754)
# Epoch [46/50], Iter [140/0] Loss: 1.5358, 2.0815, 3.6173
# tensor(0.5726)
# Epoch [46/50], Iter [160/0] Loss: 1.4377, 1.9259, 3.3636
# tensor(0.5738)
# Epoch [46/50], Iter [180/0] Loss: 1.6542, 2.2270, 3.8812
# [46/50] Loss: 4.289
# 50000
# Accuracy of the network on the 50000 train images coarse: 58 %
# Accuracy of the network on the 50000 train images fine: 50 %
# Average Accuracy of the network on the 50000 train images: 54 %
# Accuracy of the network on the 10000 test images coarse: 43 %
# Accuracy of the network on the 10000 test images fine: 32 %
# Average Accuracy of the network on the 10000 test images: 37 %
# tensor(0.5780)
# Epoch [47/50], Iter [20/0] Loss: 1.4940, 2.0465, 3.5406
# tensor(0.5736)
# Epoch [47/50], Iter [40/0] Loss: 1.3603, 1.8301, 3.1905
# tensor(0.5776)
# Epoch [47/50], Iter [60/0] Loss: 1.2819, 1.7528, 3.0348
# tensor(0.5888)
# Epoch [47/50], Iter [80/0] Loss: 1.4652, 2.0978, 3.5630
# tensor(0.6111)
# Epoch [47/50], Iter [100/0] Loss: 1.3454, 2.1145, 3.4599
# tensor(0.5825)
# Epoch [47/50], Iter [120/0] Loss: 1.4104, 1.9679, 3.3783
# tensor(0.5760)
# Epoch [47/50], Iter [140/0] Loss: 1.4382, 1.9540, 3.3921
# tensor(0.5848)
# Epoch [47/50], Iter [160/0] Loss: 1.4872, 2.0948, 3.5821
# tensor(0.5878)
# Epoch [47/50], Iter [180/0] Loss: 1.4592, 2.0807, 3.5398
# [47/50] Loss: 4.269
# 50000
# Accuracy of the network on the 50000 train images coarse: 58 %
# Accuracy of the network on the 50000 train images fine: 50 %
# Average Accuracy of the network on the 50000 train images: 54 %
# Accuracy of the network on the 10000 test images coarse: 42 %
# Accuracy of the network on the 10000 test images fine: 33 %
# Average Accuracy of the network on the 10000 test images: 37 %
# tensor(0.5970)
# Epoch [48/50], Iter [20/0] Loss: 1.2155, 1.8008, 3.0163
# tensor(0.5879)
# Epoch [48/50], Iter [40/0] Loss: 1.3339, 1.9026, 3.2365
# tensor(0.5810)
# Epoch [48/50], Iter [60/0] Loss: 1.4037, 1.9468, 3.3505
# tensor(0.5805)
# Epoch [48/50], Iter [80/0] Loss: 1.4689, 2.0327, 3.5016
# tensor(0.5854)
# Epoch [48/50], Iter [100/0] Loss: 1.2888, 1.8199, 3.1086
# tensor(0.5793)
# Epoch [48/50], Iter [120/0] Loss: 1.4058, 1.9357, 3.3415
# tensor(0.5919)
# Epoch [48/50], Iter [140/0] Loss: 1.4742, 2.1382, 3.6125
# tensor(0.5888)
# Epoch [48/50], Iter [160/0] Loss: 1.3457, 1.9270, 3.2727
# tensor(0.5977)
# Epoch [48/50], Iter [180/0] Loss: 1.2686, 1.8844, 3.1530
# [48/50] Loss: 4.249
# 50000
# Accuracy of the network on the 50000 train images coarse: 58 %
# Accuracy of the network on the 50000 train images fine: 50 %
# Average Accuracy of the network on the 50000 train images: 54 %
# Accuracy of the network on the 10000 test images coarse: 42 %
# Accuracy of the network on the 10000 test images fine: 33 %
# Average Accuracy of the network on the 10000 test images: 37 %
# tensor(0.5658)
# Epoch [49/50], Iter [20/0] Loss: 1.4609, 1.9040, 3.3649
# tensor(0.5904)
# Epoch [49/50], Iter [40/0] Loss: 1.2132, 1.7486, 2.9619
# tensor(0.5779)
# Epoch [49/50], Iter [60/0] Loss: 1.3299, 1.8208, 3.1507
# tensor(0.5825)
# Epoch [49/50], Iter [80/0] Loss: 1.3716, 1.9133, 3.2849
# tensor(0.5864)
# Epoch [49/50], Iter [100/0] Loss: 1.3090, 1.8560, 3.1650
# tensor(0.5607)
# Epoch [49/50], Iter [120/0] Loss: 1.3709, 1.7500, 3.1208
# tensor(0.5846)
# Epoch [49/50], Iter [140/0] Loss: 1.3916, 1.9586, 3.3502
# tensor(0.5829)
# Epoch [49/50], Iter [160/0] Loss: 1.3797, 1.9285, 3.3082
# tensor(0.5979)
# Epoch [49/50], Iter [180/0] Loss: 1.4448, 2.1481, 3.5929
# [49/50] Loss: 4.230
# 50000
# Accuracy of the network on the 50000 train images coarse: 58 %
# Accuracy of the network on the 50000 train images fine: 50 %
# Average Accuracy of the network on the 50000 train images: 54 %
# Accuracy of the network on the 10000 test images coarse: 42 %
# Accuracy of the network on the 10000 test images fine: 32 %
# Average Accuracy of the network on the 10000 test images: 37 %
# tensor(0.5723)
# Epoch [50/50], Iter [20/0] Loss: 1.3300, 1.7797, 3.1096
# tensor(0.5779)
# Epoch [50/50], Iter [40/0] Loss: 1.2369, 1.6934, 2.9303
# tensor(0.5823)
# Epoch [50/50], Iter [60/0] Loss: 1.4640, 2.0411, 3.5050
# tensor(0.5990)
# Epoch [50/50], Iter [80/0] Loss: 1.4627, 2.1851, 3.6477
# tensor(0.5808)
# Epoch [50/50], Iter [100/0] Loss: 1.2890, 1.7858, 3.0748
# tensor(0.6054)
# Epoch [50/50], Iter [120/0] Loss: 1.1200, 1.7182, 2.8381
# tensor(0.5747)
# Epoch [50/50], Iter [140/0] Loss: 1.4431, 1.9497, 3.3928
# tensor(0.5828)
# Epoch [50/50], Iter [160/0] Loss: 1.2737, 1.7793, 3.0530
# tensor(0.5926)
# Epoch [50/50], Iter [180/0] Loss: 1.4207, 2.0666, 3.4873
# [50/50] Loss: 4.211
# 50000
# Accuracy of the network on the 50000 train images coarse: 57 %
# Accuracy of the network on the 50000 train images fine: 50 %
# Average Accuracy of the network on the 50000 train images: 53 %
# Accuracy of the network on the 10000 test images coarse: 42 %
# Accuracy of the network on the 10000 test images fine: 32 %
# Average Accuracy of the network on the 10000 test images: 37 %

# %%
#plot train/val accuracies
plt.title("Train/Test Acc")
plt.xlabel("epoch")
plt.ylabel('acc')
line1 = plt.plot(train_acc, color='red')
line2 = plt.plot(val_acc, color='blue')
plt.legend(['Train', 'Test'], loc='upper left')
plt.savefig('521.png')   # save the figure to file
plt.show()
plt.close()

# %%
#plot train/val accuracies
plt.title("Coarse Train/Test Acc")
plt.xlabel("epoch")
plt.ylabel('acc')
line3 = plt.plot(trainc_acc, color='red', ls='dashed')
line4 = plt.plot(valc_acc, color='blue', ls='dashed')
plt.legend(['Train', 'Test'], loc='upper left')
plt.savefig('522.png')   # save the figure to file
plt.show()
plt.close()

# %%
#plot train/val accuracies
plt.title("Fine Train/Test Acc")
plt.xlabel("epoch")
plt.ylabel('acc')
line5 = plt.plot(trainf_acc, color='red', ls='dotted')
line6 = plt.plot(valf_acc, color='blue', ls='dotted')
plt.legend(['Train', 'Test'], loc='upper left')
plt.savefig('523.png')   # save the figure to file
plt.show()
plt.close()

# %%
#plot train/val accuracies
plt.title("Coarse/Fine/Total Loss")
plt.xlabel("epoch")
plt.ylabel('loss')
line7 = plt.plot(loss_history, color='red')
line8 = plt.plot(lossc_history, color='blue')
line9 = plt.plot(lossf_history, color='green')
plt.legend(['Total', 'Coarse', 'Fine'], loc='upper left')
plt.savefig('524.png')   # save the figure to file
plt.show()
plt.close()
