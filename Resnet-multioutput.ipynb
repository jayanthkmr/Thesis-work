# %%
"""Trains a ResNet on the CIFAR10 dataset.
ResNet v1
[a] Deep Residual Learning for Image Recognition
https://arxiv.org/pdf/1512.03385.pdf
ResNet v2
[b] Identity Mappings in Deep Residual Networks
https://arxiv.org/pdf/1603.05027.pdf
"""

from __future__ import print_function
import keras
from keras.layers import Dense, Conv2D, BatchNormalization, Activation
from keras.layers import AveragePooling2D, Input, Flatten
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import l2
from keras import backend as K
from keras.models import Model
from keras.datasets import cifar100
import numpy as np
import os
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot
from keras.utils import plot_model
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %%
# Training parameters
batch_size = 32  # orig paper trained all networks with batch_size=128
epochs = 50
data_augmentation = False
num_classes = 20
num_classesf = 100

# Subtracting pixel mean improves accuracy
subtract_pixel_mean = True

# Model parameter
# ----------------------------------------------------------------------------
#           |      | 200-epoch | Orig Paper| 200-epoch | Orig Paper| sec/epoch
# Model     |  n   | ResNet v1 | ResNet v1 | ResNet v2 | ResNet v2 | GTX1080Ti
#           |v1(v2)| %Accuracy | %Accuracy | %Accuracy | %Accuracy | v1 (v2)
# ----------------------------------------------------------------------------
# ResNet20  | 3 (2)| 92.16     | 91.25     | -----     | -----     | 35 (---)
# ResNet32  | 5(NA)| 92.46     | 92.49     | NA        | NA        | 50 ( NA)
# ResNet44  | 7(NA)| 92.50     | 92.83     | NA        | NA        | 70 ( NA)
# ResNet56  | 9 (6)| 92.71     | 93.03     | 93.01     | NA        | 90 (100)
# ResNet110 |18(12)| 92.65     | 93.39+-.16| 93.15     | 93.63     | 165(180)
# ResNet164 |27(18)| -----     | 94.07     | -----     | 94.54     | ---(---)
# ResNet1001| (111)| -----     | 92.39     | -----     | 95.08+-.14| ---(---)
# ---------------------------------------------------------------------------
n = 2

# Model version
# Orig paper: version = 1 (ResNet v1), Improved ResNet: version = 2 (ResNet v2)
version = 1

# Computed depth from supplied model parameter n
if version == 1:
    depth = n * 6 + 2
elif version == 2:
    depth = n * 9 + 2

# Model name, depth and version
model_type = 'ResNet%dv%d' % (depth, version)

# Load the CIFAR10 data.
(x_train, y_train), (x_test, y_test) = cifar100.load_data('coarse')
(xf_train, yf_train), (xf_test, yf_test) = cifar100.load_data('fine')


# Input image dimensions.
input_shape = x_train.shape[1:]

# Normalize data.
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# If subtract pixel mean is enabled
if subtract_pixel_mean:
    x_train_mean = np.mean(x_train, axis=0)
    x_train -= x_train_mean
    x_test -= x_train_mean

print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# Convert class vectors to binary class matrices.
yf_train = keras.utils.to_categorical(yf_train, num_classesf)
yf_test = keras.utils.to_categorical(yf_test, num_classesf)

print('y_train shape:', y_train.shape)
print('yf_train shape:', yf_train.shape)
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# y_train shape: (50000, 20)
# yf_train shape: (50000, 100)

# %%
def lr_schedule(epoch):
    """Learning Rate Schedule
    Learning rate is scheduled to be reduced after 80, 120, 160, 180 epochs.
    Called automatically every epoch as part of callbacks during training.
    # Arguments
        epoch (int): The number of epochs
    # Returns
        lr (float32): learning rate
    """
    lr = 1e-3
    if epoch > 180:
        lr *= 0.5e-3
    elif epoch > 160:
        lr *= 1e-3
    elif epoch > 120:
        lr *= 1e-2
    elif epoch > 80:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr


def resnet_layer(inputs,
                 num_filters=16,
                 kernel_size=3,
                 strides=1,
                 activation='relu',
                 batch_normalization=True,
                 conv_first=True):
    """2D Convolution-Batch Normalization-Activation stack builder
    # Arguments
        inputs (tensor): input tensor from input image or previous layer
        num_filters (int): Conv2D number of filters
        kernel_size (int): Conv2D square kernel dimensions
        strides (int): Conv2D square stride dimensions
        activation (string): activation name
        batch_normalization (bool): whether to include batch normalization
        conv_first (bool): conv-bn-activation (True) or
            bn-activation-conv (False)
    # Returns
        x (tensor): tensor as input to the next layer
    """
    conv = Conv2D(num_filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))

    x = inputs
    if conv_first:
        x = conv(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
        x = conv(x)
    return x


def resnet_v1(input_shape, depth, num_classes=20, num_classesf=100):
    """ResNet Version 1 Model builder [a]
    Stacks of 2 x (3 x 3) Conv2D-BN-ReLU
    Last ReLU is after the shortcut connection.
    At the beginning of each stage, the feature map size is halved (downsampled)
    by a convolutional layer with strides=2, while the number of filters is
    doubled. Within each stage, the layers have the same number filters and the
    same number of filters.
    Features maps sizes:
    stage 0: 32x32, 16
    stage 1: 16x16, 32
    stage 2:  8x8,  64
    The Number of parameters is approx the same as Table 6 of [a]:
    ResNet20 0.27M
    ResNet32 0.46M
    ResNet44 0.66M
    ResNet56 0.85M
    ResNet110 1.7M
    # Arguments
        input_shape (tensor): shape of input image tensor
        depth (int): number of core convolutional layers
        num_classes (int): number of classes (CIFAR10 has 10)
    # Returns
        model (Model): Keras model instance
    """
    if (depth - 2) % 6 != 0:
        raise ValueError('depth should be 6n+2 (eg 20, 32, 44 in [a])')
    # Start model definition.
    num_filters = 16
    num_res_blocks = int((depth - 2) / 6)

    inputs = Input(shape=input_shape)
    x = resnet_layer(inputs=inputs)
    # Instantiate the stack of residual units
    for stack in range(3):
        for res_block in range(num_res_blocks):
            strides = 1
            if stack > 0 and res_block == 0:  # first layer but not first stack
                strides = 2  # downsample
            y = resnet_layer(inputs=x,
                             num_filters=num_filters,
                             strides=strides)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters,
                             activation=None)
            if stack > 0 and res_block == 0:  # first layer but not first stack
                # linear projection residual shortcut connection to match
                # changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.add([x, y])
            x = Activation('relu')(x)
        num_filters *= 2

    # Add classifier on top.
    # v1 does not use BN after last shortcut connection-ReLU
    x = AveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    outputc = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)
    outputf = Dense(num_classesf,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=[outputc, outputf])
    return model


def resnet_v2(input_shape, depth, num_classes=20, num_classesf=100):
    """ResNet Version 2 Model builder [b]
    Stacks of (1 x 1)-(3 x 3)-(1 x 1) BN-ReLU-Conv2D or also known as
    bottleneck layer
    First shortcut connection per layer is 1 x 1 Conv2D.
    Second and onwards shortcut connection is identity.
    At the beginning of each stage, the feature map size is halved (downsampled)
    by a convolutional layer with strides=2, while the number of filter maps is
    doubled. Within each stage, the layers have the same number filters and the
    same filter map sizes.
    Features maps sizes:
    conv1  : 32x32,  16
    stage 0: 32x32,  64
    stage 1: 16x16, 128
    stage 2:  8x8,  256
    # Arguments
        input_shape (tensor): shape of input image tensor
        depth (int): number of core convolutional layers
        num_classes (int): number of classes (CIFAR10 has 10)
    # Returns
        model (Model): Keras model instance
    """
    if (depth - 2) % 9 != 0:
        raise ValueError('depth should be 9n+2 (eg 56 or 110 in [b])')
    # Start model definition.
    num_filters_in = 16
    num_res_blocks = int((depth - 2) / 9)

    inputs = Input(shape=input_shape)
    # v2 performs Conv2D with BN-ReLU on input before splitting into 2 paths
    x = resnet_layer(inputs=inputs,
                     num_filters=num_filters_in,
                     conv_first=True)

    # Instantiate the stack of residual units
    for stage in range(3):
        for res_block in range(num_res_blocks):
            activation = 'relu'
            batch_normalization = True
            strides = 1
            if stage == 0:
                num_filters_out = num_filters_in * 4
                if res_block == 0:  # first layer and first stage
                    activation = None
                    batch_normalization = False
            else:
                num_filters_out = num_filters_in * 2
                if res_block == 0:  # first layer but not first stage
                    strides = 2    # downsample

            # bottleneck residual unit
            y = resnet_layer(inputs=x,
                             num_filters=num_filters_in,
                             kernel_size=1,
                             strides=strides,
                             activation=activation,
                             batch_normalization=batch_normalization,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_in,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_out,
                             kernel_size=1,
                             conv_first=False)
            if res_block == 0:
                # linear projection residual shortcut connection to match
                # changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters_out,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.add([x, y])

        num_filters_in = num_filters_out

    # Add classifier on top.
    # v2 has BN-ReLU before Pooling
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = AveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    outputc = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)
    outputf = Dense(num_classesf,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=[outputc, outputf])
    return model

# %%
if version == 2:
    model = resnet_v2(input_shape=input_shape, depth=depth)
else:
    model = resnet_v1(input_shape=input_shape, depth=depth)

opt = Adam(lr=lr_schedule(0))

model.compile(loss='categorical_crossentropy',
              optimizer=opt, loss_weights=[1.,1.])
model.summary()
print(model_type)
# Out:
# Learning rate:  0.001
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 16)   448         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 32, 32, 16)   64          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 32, 32, 16)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 16)   2320        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 32, 32, 16)   64          conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 32, 32, 16)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 32, 32, 16)   2320        activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 32, 32, 16)   64          conv2d_3[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 32, 32, 16)   0           activation_1[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 32, 32, 16)   0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 16)   2320        activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 32, 32, 16)   64          conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 32, 32, 16)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 16)   2320        activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 32, 32, 16)   64          conv2d_5[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 32, 32, 16)   0           activation_3[0][0]
#                                                                  batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 32, 32, 16)   0           add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 16, 16, 32)   4640        activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 16, 16, 32)   128         conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 16, 16, 32)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 16, 16, 32)   9248        activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 32)   544         activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 16, 16, 32)   128         conv2d_7[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 16, 16, 32)   0           conv2d_8[0][0]
#                                                                  batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 16, 16, 32)   0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 32)   9248        activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 16, 16, 32)   128         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 16, 16, 32)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 16, 32)   9248        activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 16, 16, 32)   128         conv2d_10[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 16, 16, 32)   0           activation_7[0][0]
#                                                                  batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 16, 16, 32)   0           add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 8, 8, 64)     18496       activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 8, 8, 64)     256         conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 8, 8, 64)     0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 8, 8, 64)     36928       activation_10[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 8, 8, 64)     2112        activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 8, 8, 64)     256         conv2d_12[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 8, 8, 64)     0           conv2d_13[0][0]
#                                                                  batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 8, 8, 64)     0           add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 8, 8, 64)     36928       activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 8, 8, 64)     256         conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 8, 8, 64)     0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 8, 8, 64)     36928       activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 8, 8, 64)     256         conv2d_15[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 8, 8, 64)     0           activation_11[0][0]
#                                                                  batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 8, 8, 64)     0           add_6[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 1, 1, 64)     0           activation_13[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 64)           0           average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 20)           1300        flatten_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 100)          6500        flatten_1[0][0]
# ==================================================================================================
# Total params: 183,704
# Trainable params: 182,776
# Non-trainable params: 928
# __________________________________________________________________________________________________
# ResNet14v1

# %%
plot_model(model, to_file='model_resnet.png')
SVG(model_to_dot(model).create(prog='dot', format='svg'))

# %%
# Prepare model model saving directory.
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'cifar10_%s_model.{epoch:03d}.h5' % model_type
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)

# Prepare callbacks for model saving and for learning rate adjustment.
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_acc',
                             verbose=1,
                             save_best_only=True)

lr_scheduler = LearningRateScheduler(lr_schedule)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)

callbacks = [checkpoint, lr_reducer, lr_scheduler]

# %%
print('Not using data augmentation.')
history = model.fit(x_train, [y_train, yf_train],
          batch_size=batch_size,
          epochs=epochs,
          validation_data=(x_test, [y_test, yf_test]),
          shuffle=True,
          callbacks=callbacks)
# Out:
# Not using data augmentation.
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# Learning rate:  0.001
# 50000/50000 [==============================] - 626s 13ms/step - loss: 6.2845 - dense_1_loss: 2.3592 - dense_2_loss: 3.8067 - val_loss: 5.5937 - val_dense_1_loss: 2.1136 - val_dense_2_loss: 3.3538
# Epoch 2/50
# Learning rate:  0.001
# /usr/local/lib/python2.7/site-packages/keras/callbacks.py:434: RuntimeWarning: Can save best model only with val_acc available, skipping.
#   'skipping.' % (self.monitor), RuntimeWarning)
# 50000/50000 [==============================] - 623s 12ms/step - loss: 5.1137 - dense_1_loss: 1.9147 - dense_2_loss: 3.0638 - val_loss: 5.0471 - val_dense_1_loss: 1.9030 - val_dense_2_loss: 3.0002
# Epoch 3/50
# Learning rate:  0.001
# 50000/50000 [==============================] - 1036s 21ms/step - loss: 4.5486 - dense_1_loss: 1.6969 - dense_2_loss: 2.6993 - val_loss: 4.8734 - val_dense_1_loss: 1.8710 - val_dense_2_loss: 2.8417
# Epoch 4/50
# Learning rate:  0.001
# 50000/50000 [==============================] - 455s 9ms/step - loss: 4.1597 - dense_1_loss: 1.5389 - dense_2_loss: 2.4522 - val_loss: 4.3265 - val_dense_1_loss: 1.6335 - val_dense_2_loss: 2.5167
# Epoch 5/50
# Learning rate:  0.001
# 50000/50000 [==============================] - 459s 9ms/step - loss: 3.8837 - dense_1_loss: 1.4269 - dense_2_loss: 2.2731 - val_loss: 4.1944 - val_dense_1_loss: 1.5490 - val_dense_2_loss: 2.4547
# Epoch 6/50
# Learning rate:  0.001
# 50000/50000 [==============================] - 471s 9ms/step - loss: 3.6614 - dense_1_loss: 1.3315 - dense_2_loss: 2.1322 - val_loss: 4.5299 - val_dense_1_loss: 1.7352 - val_dense_2_loss: 2.5902
# Epoch 7/50
# Learning rate:  0.001
# 50000/50000 [==============================] - 493s 10ms/step - loss: 3.4895 - dense_1_loss: 1.2582 - dense_2_loss: 2.0200 - val_loss: 3.9814 - val_dense_1_loss: 1.4439 - val_dense_2_loss: 2.3194
# Epoch 8/50
# Learning rate:  0.001
# 50000/50000 [==============================] - 504s 10ms/step - loss: 3.3327 - dense_1_loss: 1.1880 - dense_2_loss: 1.9203 - val_loss: 3.8744 - val_dense_1_loss: 1.4119 - val_dense_2_loss: 2.2317
# Epoch 9/50
# Learning rate:  0.001
# 50000/50000 [==============================] - 509s 10ms/step - loss: 3.2055 - dense_1_loss: 1.1293 - dense_2_loss: 1.8392 - val_loss: 4.2045 - val_dense_1_loss: 1.5763 - val_dense_2_loss: 2.3849
# Epoch 10/50
# Learning rate:  0.001
# 50000/50000 [==============================] - 512s 10ms/step - loss: 3.0824 - dense_1_loss: 1.0750 - dense_2_loss: 1.7583 - val_loss: 3.7939 - val_dense_1_loss: 1.3775 - val_dense_2_loss: 2.1611
# Epoch 11/50
# Learning rate:  0.001
# 50000/50000 [==============================] - 516s 10ms/step - loss: 2.9806 - dense_1_loss: 1.0278 - dense_2_loss: 1.6916 - val_loss: 3.9757 - val_dense_1_loss: 1.4927 - val_dense_2_loss: 2.2156
# Epoch 12/50
# Learning rate:  0.001
# 50000/50000 [==============================] - 519s 10ms/step - loss: 2.8781 - dense_1_loss: 0.9784 - dense_2_loss: 1.6268 - val_loss: 3.7834 - val_dense_1_loss: 1.3731 - val_dense_2_loss: 2.1313
# Epoch 13/50
# Learning rate:  0.001
# 50000/50000 [==============================] - 515s 10ms/step - loss: 2.7851 - dense_1_loss: 0.9367 - dense_2_loss: 1.5639 - val_loss: 3.8135 - val_dense_1_loss: 1.3822 - val_dense_2_loss: 2.1410
# Epoch 14/50
# Learning rate:  0.001
# 50000/50000 [==============================] - 515s 10ms/step - loss: 2.7066 - dense_1_loss: 0.8981 - dense_2_loss: 1.5128 - val_loss: 4.2728 - val_dense_1_loss: 1.5891 - val_dense_2_loss: 2.3823
# Epoch 15/50
# Learning rate:  0.001
# 50000/50000 [==============================] - 523s 10ms/step - loss: 2.6210 - dense_1_loss: 0.8529 - dense_2_loss: 1.4614 - val_loss: 3.9570 - val_dense_1_loss: 1.4489 - val_dense_2_loss: 2.1959
# Epoch 16/50
# Learning rate:  0.001
# 50000/50000 [==============================] - 616s 12ms/step - loss: 2.5430 - dense_1_loss: 0.8144 - dense_2_loss: 1.4115 - val_loss: 4.0971 - val_dense_1_loss: 1.5078 - val_dense_2_loss: 2.2664
# Epoch 17/50
# Learning rate:  0.001
# 50000/50000 [==============================] - 641s 13ms/step - loss: 2.4873 - dense_1_loss: 0.7865 - dense_2_loss: 1.3728 - val_loss: 3.8446 - val_dense_1_loss: 1.4035 - val_dense_2_loss: 2.1075
# Epoch 18/50
# Learning rate:  0.001
# 50000/50000 [==============================] - 3321s 66ms/step - loss: 2.4074 - dense_1_loss: 0.7456 - dense_2_loss: 1.3234 - val_loss: 4.1309 - val_dense_1_loss: 1.5056 - val_dense_2_loss: 2.2815
# Epoch 19/50
# Learning rate:  0.001
# 50000/50000 [==============================] - 473s 9ms/step - loss: 2.3539 - dense_1_loss: 0.7214 - dense_2_loss: 1.2839 - val_loss: 4.2815 - val_dense_1_loss: 1.6091 - val_dense_2_loss: 2.3183
# Epoch 20/50
# Learning rate:  0.001
# 50000/50000 [==============================] - 497s 10ms/step - loss: 2.2957 - dense_1_loss: 0.6884 - dense_2_loss: 1.2486 - val_loss: 4.2327 - val_dense_1_loss: 1.5593 - val_dense_2_loss: 2.3093
# Epoch 21/50
# Learning rate:  0.001
# 50000/50000 [==============================] - 503s 10ms/step - loss: 2.2383 - dense_1_loss: 0.6578 - dense_2_loss: 1.2121 - val_loss: 4.3161 - val_dense_1_loss: 1.5989 - val_dense_2_loss: 2.3432
# Epoch 22/50
# Learning rate:  0.001
# 50000/50000 [==============================] - 533s 11ms/step - loss: 2.1935 - dense_1_loss: 0.6357 - dense_2_loss: 1.1794 - val_loss: 4.2953 - val_dense_1_loss: 1.5744 - val_dense_2_loss: 2.3369
# Epoch 23/50
# Learning rate:  0.001
# 50000/50000 [==============================] - 567s 11ms/step - loss: 2.1364 - dense_1_loss: 0.6048 - dense_2_loss: 1.1437 - val_loss: 4.4444 - val_dense_1_loss: 1.6633 - val_dense_2_loss: 2.3878
# Epoch 24/50
# Learning rate:  0.001
# 50000/50000 [==============================] - 576s 12ms/step - loss: 2.0811 - dense_1_loss: 0.5758 - dense_2_loss: 1.1080 - val_loss: 4.4722 - val_dense_1_loss: 1.6769 - val_dense_2_loss: 2.3932
# Epoch 25/50
# Learning rate:  0.001
# 50000/50000 [==============================] - 565s 11ms/step - loss: 2.0697 - dense_1_loss: 0.5687 - dense_2_loss: 1.0946 - val_loss: 4.8641 - val_dense_1_loss: 1.8176 - val_dense_2_loss: 2.6347
# Epoch 26/50
# Learning rate:  0.001
# 50000/50000 [==============================] - 559s 11ms/step - loss: 2.0175 - dense_1_loss: 0.5426 - dense_2_loss: 1.0594 - val_loss: 4.6713 - val_dense_1_loss: 1.7598 - val_dense_2_loss: 2.4910
# Epoch 27/50
# Learning rate:  0.001
# 50000/50000 [==============================] - 553s 11ms/step - loss: 1.9851 - dense_1_loss: 0.5249 - dense_2_loss: 1.0360 - val_loss: 4.5686 - val_dense_1_loss: 1.7238 - val_dense_2_loss: 2.4155
# Epoch 28/50
# Learning rate:  0.001
# 50000/50000 [==============================] - 548s 11ms/step - loss: 1.9531 - dense_1_loss: 0.5097 - dense_2_loss: 1.0105 - val_loss: 4.6565 - val_dense_1_loss: 1.7691 - val_dense_2_loss: 2.4496
# Epoch 29/50
# Learning rate:  0.001
# 50000/50000 [==============================] - 547s 11ms/step - loss: 1.9142 - dense_1_loss: 0.4873 - dense_2_loss: 0.9859 - val_loss: 4.9112 - val_dense_1_loss: 1.8784 - val_dense_2_loss: 2.5871
# Epoch 30/50
# Learning rate:  0.001
# 50000/50000 [==============================] - 545s 11ms/step - loss: 1.8846 - dense_1_loss: 0.4689 - dense_2_loss: 0.9666 - val_loss: 4.8461 - val_dense_1_loss: 1.8205 - val_dense_2_loss: 2.5717
# Epoch 31/50
# Learning rate:  0.001
# 50000/50000 [==============================] - 546s 11ms/step - loss: 1.8697 - dense_1_loss: 0.4607 - dense_2_loss: 0.9519 - val_loss: 4.7224 - val_dense_1_loss: 1.7899 - val_dense_2_loss: 2.4706
# Epoch 32/50
# Learning rate:  0.001
# 50000/50000 [==============================] - 547s 11ms/step - loss: 1.8292 - dense_1_loss: 0.4414 - dense_2_loss: 0.9229 - val_loss: 5.5082 - val_dense_1_loss: 2.2039 - val_dense_2_loss: 2.8350
# Epoch 33/50
# Learning rate:  0.001
# 50000/50000 [==============================] - 541s 11ms/step - loss: 1.8195 - dense_1_loss: 0.4358 - dense_2_loss: 0.9111 - val_loss: 4.9305 - val_dense_1_loss: 1.8820 - val_dense_2_loss: 2.5716
# Epoch 34/50
# Learning rate:  0.001
# 50000/50000 [==============================] - 540s 11ms/step - loss: 1.8089 - dense_1_loss: 0.4279 - dense_2_loss: 0.9011 - val_loss: 4.9003 - val_dense_1_loss: 1.8544 - val_dense_2_loss: 2.5617
# Epoch 35/50
# Learning rate:  0.001
# 50000/50000 [==============================] - 552s 11ms/step - loss: 1.7738 - dense_1_loss: 0.4090 - dense_2_loss: 0.8780 - val_loss: 5.1784 - val_dense_1_loss: 1.9756 - val_dense_2_loss: 2.7117
# Epoch 36/50
# Learning rate:  0.001
# 50000/50000 [==============================] - 134572s 3s/step - loss: 1.7534 - dense_1_loss: 0.3992 - dense_2_loss: 0.8604 - val_loss: 5.3750 - val_dense_1_loss: 2.0812 - val_dense_2_loss: 2.7961
# Epoch 37/50
# Learning rate:  0.001
# 50000/50000 [==============================] - 434s 9ms/step - loss: 1.7542 - dense_1_loss: 0.3960 - dense_2_loss: 0.8578 - val_loss: 5.2475 - val_dense_1_loss: 1.9975 - val_dense_2_loss: 2.7455
# Epoch 38/50
# Learning rate:  0.001
# 50000/50000 [==============================] - 8270s 165ms/step - loss: 1.7358 - dense_1_loss: 0.3859 - dense_2_loss: 0.8427 - val_loss: 5.3735 - val_dense_1_loss: 2.0673 - val_dense_2_loss: 2.7951
# Epoch 39/50
# Learning rate:  0.001
# 50000/50000 [==============================] - 437s 9ms/step - loss: 1.7116 - dense_1_loss: 0.3777 - dense_2_loss: 0.8205 - val_loss: 5.4759 - val_dense_1_loss: 2.1351 - val_dense_2_loss: 2.8234
# Epoch 40/50
# Learning rate:  0.001
# 50000/50000 [==============================] - 444s 9ms/step - loss: 1.6983 - dense_1_loss: 0.3663 - dense_2_loss: 0.8123 - val_loss: 5.9943 - val_dense_1_loss: 2.4011 - val_dense_2_loss: 3.0699
# Epoch 41/50
# Learning rate:  0.001
# 50000/50000 [==============================] - 465s 9ms/step - loss: 1.6961 - dense_1_loss: 0.3659 - dense_2_loss: 0.8045 - val_loss: 5.4852 - val_dense_1_loss: 2.1264 - val_dense_2_loss: 2.8293
# Epoch 42/50
# Learning rate:  0.001
# 50000/50000 [==============================] - 551s 11ms/step - loss: 1.6818 - dense_1_loss: 0.3591 - dense_2_loss: 0.7908 - val_loss: 5.2839 - val_dense_1_loss: 2.0029 - val_dense_2_loss: 2.7455
# Epoch 43/50
# Learning rate:  0.001
# 50000/50000 [==============================] - 597s 12ms/step - loss: 1.6614 - dense_1_loss: 0.3492 - dense_2_loss: 0.7750 - val_loss: 5.3305 - val_dense_1_loss: 2.0189 - val_dense_2_loss: 2.7710
# Epoch 44/50
# Learning rate:  0.001
# 50000/50000 [==============================] - 548s 11ms/step - loss: 1.6501 - dense_1_loss: 0.3420 - dense_2_loss: 0.7655 - val_loss: 6.1569 - val_dense_1_loss: 2.4713 - val_dense_2_loss: 3.1396
# Epoch 45/50
# Learning rate:  0.001
# 50000/50000 [==============================] - 556s 11ms/step - loss: 1.6471 - dense_1_loss: 0.3364 - dense_2_loss: 0.7628 - val_loss: 5.8218 - val_dense_1_loss: 2.2652 - val_dense_2_loss: 3.0049
# Epoch 46/50
# Learning rate:  0.001
# 50000/50000 [==============================] - 566s 11ms/step - loss: 1.6320 - dense_1_loss: 0.3289 - dense_2_loss: 0.7500 - val_loss: 5.8704 - val_dense_1_loss: 2.2931 - val_dense_2_loss: 3.0207
# Epoch 47/50
# Learning rate:  0.001
# 50000/50000 [==============================] - 563s 11ms/step - loss: 1.6379 - dense_1_loss: 0.3315 - dense_2_loss: 0.7480 - val_loss: 6.1091 - val_dense_1_loss: 2.4219 - val_dense_2_loss: 3.1253
# Epoch 48/50
# Learning rate:  0.001
# 50000/50000 [==============================] - 563s 11ms/step - loss: 1.6123 - dense_1_loss: 0.3203 - dense_2_loss: 0.7286 - val_loss: 5.5310 - val_dense_1_loss: 2.1115 - val_dense_2_loss: 2.8531
# Epoch 49/50
# Learning rate:  0.001
# 50000/50000 [==============================] - 687s 14ms/step - loss: 1.6055 - dense_1_loss: 0.3156 - dense_2_loss: 0.7221 - val_loss: 5.7665 - val_dense_1_loss: 2.2384 - val_dense_2_loss: 2.9571
# Epoch 50/50
# Learning rate:  0.001
# 50000/50000 [==============================] - 544s 11ms/step - loss: 1.6005 - dense_1_loss: 0.3133 - dense_2_loss: 0.7148 - val_loss: 5.7809 - val_dense_1_loss: 2.2728 - val_dense_2_loss: 2.9322

# %%
# Plot training & validation accuracy values
plt.plot(history.history['dense_1_loss'])
plt.plot(history.history['val_dense_1_loss'])
plt.title('Model loss')
plt.ylabel('Coarse label loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.savefig('102.png')   # save the figure to file
plt.show()
plt.close()

fig = plt.plot(history.history['dense_2_loss'])
plt.plot(history.history['val_dense_2_loss'])
plt.title('Model loss')
plt.ylabel('Fine label loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.savefig('101.png')   # save the figure to file
plt.show()
plt.close()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.savefig('103.png')   # save the figure to file
plt.show()
plt.close()

# %%
# Score trained model.
scores = model.evaluate(x_test, [y_test, yf_test], verbose=1)
print('Test loss:', scores[0])
# Out:
# 10000/10000 [==============================] - 24s 2ms/step
# Test loss: 5.780872454833984

# %%
l = model.predict(x_test)
l_cp = np.argmax(l[0], axis=1)
l_fp = np.argmax(l[1], axis=1)
y_testa = y_test.flatten()
yf_testa = yf_test.flatten()
scoremultc = 0
scoremultf = 0
for i in range(10000):
    if y_testa[i]== l_cp[i]:
        scoremultc+=1
    if yf_testa[i]== l_fp[i]:
        scoremultf+=1
scoremultc = scoremultc/10000.0
scoremultf = scoremultf/10000.0
print('Coarse accuracy:', scoremultc)
print('Fine accuracy:', scoremultf)
print('Test accuracy:', (scoremultf + scoremultc)/2.0)
# Out:
# Coarse accuracy: 0.0761
# Fine accuracy: 0.012
# Test accuracy: 0.04405
